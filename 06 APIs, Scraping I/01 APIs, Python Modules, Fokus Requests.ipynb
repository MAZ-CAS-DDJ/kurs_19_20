# %% [markdown]
# # APIs, Libraries, Modules -> "Requests"
# Gezielt und automatisiert Daten im Web auslesen

# %% [markdown]
# Zuerst installieren wir pandas und requests. Das können wir von der Command line mit den Befehlen ```pip install requests``` und ```pip install pandas``` die beiden Module installieren. Oder direkt hier in Jupyter Notebook mit ```!pip install requests``` und ```!pip install pandas```.

# %% [markdown]
# Die Python-Library erlaubt es, automatisiert URLs zu besuchen und gezielt Inhalte herauszulesen. Der Untertitel in [der Dokumentation](http://docs.python-requests.org/en/master/) fasst eigentlich am besten zusammen, was ```requests``` ist: "HTTP for Humans." HTTP steht für Hyper Text Transfer Protocol und ist die Technologie, die Tim Berners-Lee im Jahr 1990 erfunden hat. Ohne HTTP kein Internet. Mit ```Requests```können wir Websites viel genauer befragen, als wir das mit Wget letzte Woche kennengelernt haben.

# %% [markdown]
# ### Unsere Imports

# %%
import requests
import pandas as pd #diese Library werdet ihr am Mittwoch und Donnerstag viel genauer anschauen

# %% [markdown]
# Zur Dokumentation von ```requests``` geht es [hier lang](http://docs.python-requests.org/en/master/).

# %% [markdown]
# ### Notes

# %% [markdown]
# In einer ersten Übung arbeiten wir mit [der API des USGS](https://earthquake.usgs.gov/fdsnws/event/1/#methods) arbeiten. Für die meisten API muss man sich heutezutage eine eigene API-Key kreieren. Doch diese API braucht keine Keys. Deshalb ist es ein gutes Kennenlernbeispiel.

# %% [markdown]
# Falls Probleme mit dem Output auftauchen, hier ein Work around für die Meldung, dass der Output limitiert wurde. [Reconfigure line output](https://stackoverflow.com/questions/43288550/iopub-data-rate-exceeded-when-viewing-image-in-jupyter-notebook) and [opening stuff from the command line](https://stackoverflow.com/questions/16344709/how-to-open-a-file-from-the-command-line-with-a-specified-program)

# %% [markdown]
# ### Dokumentation

# %% [markdown]
# Bevor man mit deiner API arbeitet, lohnt es sich immer zuerst, die [Dokumentation](https://earthquake.usgs.gov/fdsnws/event/1/#parameters) anzuschauen.

# %% [markdown]
# ### Erste Abfragen

# %% [markdown]
# Kleinere Abfrage. Wieviele Erdbeben hat es in einem bestimmten Zeitraum gegeben?

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n  <title>API Documentation - Earthquake Catalog</title>\n  <meta charset="utf-8"/>\n  <meta name="viewport" content="width=device-width, initial-scale=1"/>\n  <link rel="stylesheet" href="/theme/site/earthquake/index.css"/><meta name="description" content="USGS Earthquake Hazards Program, responsible for monitoring, reporting, and researching earthquakes and earthquake hazards"/><meta name="keywords" content="aftershock,earthquake,epicenter,fault,foreshock,geologist,geophysics,hazard,hypocenter,intensity,intensity scale,magnitude,magnitude scale,mercalli,plate,richter,seismic,seismicity,seismogram,seismograph,seismologist,seismology,subduction,tectonics,tsunami,quake,sismologico,sismologia"/><script id="_fed_an_ua_tag" async="async" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=DOI&amp;subagency=USGS"></script>  <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons|Merriweather:400,400italic,700|Source+Sans+Pro:400,300,700"/>\n</head>\n<body>\n\n  <header role="banner" class="site-header">\n    <a class="site-logo" href="/" title="U.S. Geological Survey">\n      <img src="/theme/images/usgs-logo.svg" alt=""/>\n    </a>\n    <a class="jumplink-navigation" href="#site-sectionnav">Jump to Navigation</a>\n      </header>\n\n  <main role="main" class="page" aria-labelledby="page-header">\n    <header class="page-header" id="page-header">\n      <h1>API Documentation - Earthquake Catalog</h1>\n    </header>\n\n    <div class="page-content">\n      \n<p>\n  This is an implementation of the\n  <a href="http://www.fdsn.org/webservices/FDSN-WS-Specifications-1.0.pdf">\n      FDSN Event Web Service Specification</a>,\n  and allows custom searches for earthquake information using a variety of\n  parameters.\n</p>\n<p class="alert info">Please note that automated applications should use\n  <a href="/earthquakes/feed/v1.0/geojson.php">\n      Real-time GeoJSON Feeds</a>\n  for displaying earthquake information whenever possible, as they will have\n  the best performance and availability for that type of information.\n</p>\n\n\n<h2 id="url">URL</h2>\n<p>\n  https://earthquake.usgs.gov/fdsnws/event/1/[<a href="#methods">METHOD</a>[?<a href="#parameters">PARAMETERS</a>]]\n</p>\n\n\n<h2 id="methods">Methods</h2>\n<dl class="vertical">\n  <dt>application.json</dt>\n  <dd>\n      request known enumerated parameter values for the interface.\n  </dd>\n  <dd>\n    <ul class="examples">\n      <li>\n        <a href="https://earthquake.usgs.gov/fdsnws/event/1/application.json">\n            https://earthquake.usgs.gov/fdsnws/event/1/application.json</a>\n      </li>\n    </ul>\n  </dd>\n  <dt>application.wadl</dt>\n  <dd>\n    request <abbr title="Web Application Description Language">WADL</abbr>\n    for the interface.\n  </dd>\n  <dd>\n    <ul class="examples">\n      <li>\n        <a href="https://earthquake.usgs.gov/fdsnws/event/1/application.wadl">\n            https://earthquake.usgs.gov/fdsnws/event/1/application.wadl</a>\n      </li>\n    </ul>\n  </dd>\n  <dt>catalogs</dt>\n  <dd>request available catalogs.</dd>\n  <dd>\n    <ul class="examples">\n      <li>\n        <a href="https://earthquake.usgs.gov/fdsnws/event/1/catalogs">\n            https://earthquake.usgs.gov/fdsnws/event/1/catalogs</a>\n      </li>\n    </ul>\n  </dd>\n  <dt>contributors</dt>\n  <dd>\n    request available contributors\n  </dd>\n  <dd>\n    <ul class="examples">\n      <li>\n        <a href="https://earthquake.usgs.gov/fdsnws/event/1/contributors">\n            https://earthquake.usgs.gov/fdsnws/event/1/contributors</a>\n      </li>\n    </ul>\n  </dd>\n  <dt>count</dt>\n  <dd>\n    to perform a count on a data request. Count uses the same\n    <a href="#parameters">parameters</a> as the query method, and is\n    availablein these <a href="#format">formats</a>: plain text (default),\n    geojson, and xml.\n  </dd>\n  <dd>\n    <ul>\n      <li><a href="https://earthquake.u ...

# %% [markdown]
# Wieviele hat es letzte Nacht von x bis x gegeben? Dafür müssen wir in der Dokumentation Time nachfragen.

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2019-09-01&endtime=2019-09-30'

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '9529'

# %% [markdown]
# Wegen Zeitverschiebung Zeit anpassen.

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2019-09-01T24:00:00&endtime=2019-09-30T08:00:00'

# %%
response = requests.get(url)
response.text
# Out:
# '8886'

# %% [markdown]
# ### Grosse, komibinierte Abfrage

# %% [markdown]
# Details zu allen Erbeben in den über drei Tage, 18-7-2017 bis 31-7-2017.

# %%
url1 = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson'

# %%
urlzeit = '&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00'

# %%
url1 + urlzeit
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00'

# %%
response = requests.get(url1+urlzeit)
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1568993538000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.8.1',
#   'count': 1475},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.45,
#     'place': '5km SSW of Volcano, Hawaii',
#     'time': 1533023876310,
#     'updated': 1533052838207,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501722',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501722&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 92,
#     'net': 'hv',
#     'code': '70501722',
#     'ids': ',hv70501722,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.01182,
#     'rms': 0.3,
#     'gap': 95,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 5km SSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2603302, 19.3876667, -0.15]},
#    'id': 'hv70501722'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.28,
#     'place': '4km SW of Mammoth Lakes, CA',
#     'time': 1533023810000,
#     'updated': 1533077215403,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73061846',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73061846&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nc',
#     'code': '73061846',
#     'ids': ',nc73061846,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.005685,
#     'rms': 0.03,
#     'gap': 157,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 4km SW of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-119.0141667, 37.6131667, 0.96]},
#    'id': 'nc73061846'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '3km SW of Volcano, Hawaii',
#     'time': 1533023693860,
#     'updated': 1533024043540,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501717',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501717&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 123,
#     'net': 'hv',
#     'code': '70501717',
#     'ids': ',hv70501717,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 41,
#     'dmin': 0.008641,
#     'rms': 0.25,
#     'gap': 43,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 3km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2584991, 19.4034996, -0.28]},
#    'id': 'hv70501717'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.84,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533023666030,
#     'updated': 1533024011850,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501712',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501712&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 124,
#     'net': 'hv',
#     'code': '70501712',
#     'ids': ',hv70501712,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.003559,
#     'rms': 0.14,
#     'gap': 89,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2704926, 19.3973331, 0.93]},
#    'id': 'hv70501712'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.34,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533023616600,
#     'updated': 1533023958180,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501702',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501702&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 84,
#     'net': 'hv',
#     'code': '70501702',
#     'ids': ',hv70501702,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.00453,
#     'rms': 0.2,
#     'gap': 61,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2681732, 19.3941669, 0.41]},
#    'id': 'hv70501702'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '5km WSW of Volcano, Hawaii',
#     'time': 1533023372360,
#     'updated': 1533023716140,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501687',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501687&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 123,
#     'net': 'hv',
#     'code': '70501687',
#     'ids': ',hv70501687,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.003424,
#     'rms': 0.14,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2871704, 19.4158325, 1.19]},
#    'id': 'hv70501687'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.03,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533023295880,
#     'updated': 1533052242767,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501677',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501677&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 141,
#     'net': 'hv',
#     'code': '70501677',
#     'ids': ',hv70501677,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 44,
#     'dmin': 0.004676,
#     'rms': 0.28,
#     'gap': 43,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2723389, 19.3908329, 0.2]},
#    'id': 'hv70501677'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.7,
#     'place': '11km W of Toms Place, CA',
#     'time': 1533023268630,
#     'updated': 1533077034679,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73061841',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73061841&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'nc',
#     'code': '73061841',
#     'ids': ',nc73061841,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.03276,
#     'rms': 0.05,
#     'gap': 284,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 11km W of Toms Place, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8066667, 37.5625, 1.76]},
#    'id': 'nc73061841'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533023175370,
#     'updated': 1533023517520,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501667',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501667&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'hv',
#     'code': '70501667',
#     'ids': ',hv70501667,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 39,
#     'dmin': 0.006067,
#     'rms': 0.27,
#     'gap': 50,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2681732, 19.3921661, 0.08]},
#    'id': 'hv70501667'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.83,
#     'place': '6km SE of Mammoth Lakes, CA',
#     'time': 1533023098750,
#     'updated': 1533605530545,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73061831',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73061831&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'nc',
#     'code': '73061831',
#     'ids': ',nc73061831,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.01046,
#     'rms': 0.04,
#     'gap': 164,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 6km SE of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.9266667, 37.6068333, 1.71]},
#    'id': 'nc73061831'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.43,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533022920840,
#     'updated': 1548805892532,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501657',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501657&format=geojson',
#     'felt': 8,
#     'cdi': 2.1,
#     'mmi': 3.29,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 183,
#     'net': 'hv',
#     'code': '70501657',
#     'ids': ',hv70501657,',
#     'sources': ',hv,',
#     'types': ',dyfi,geoserve,origin,phase-data,shakemap,',
#     'nst': 35,
#     'dmin': 0.00345,
#     'rms': 0.1,
#     'gap': 38,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.2735, 19.3988333, 1.51]},
#    'id': 'hv70501657'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '35km WNW of Volcano, Hawaii',
#     'time': 1533022831110,
#     'updated': 1533023172940,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501652',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501652&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 123,
#     'net': 'hv',
#     'code': '70501652',
#     'ids': ',hv70501652,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.04391,
#     'rms': 0.24,
#     'gap': 144,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 35km WNW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.5294952, 19.6000004, -1.22]},
#    'id': 'hv70501652'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.39,
#     'place': '3km SW of Volcano, Hawaii',
#     'time': 1533022822630,
#     'updated': 1539704049040,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501647',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501647&format=geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 177,
#     'net': 'hv',
#     'code': '70501647',
#     'ids': ',hv70501647,us2000ghzd,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': 52,
#     'dmin': 0.004608,
#     'rms': 0.23,
#     'gap': 36,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 3km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2646637, 19.4130001, 0.59]},
#    'id': 'hv70501647'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.93,
#     'place': '5km W of Volcano, Hawaii',
#     'time': 1533022784630,
#     'updated': 1533023127100,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501642',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501642&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 132,
#     'net': 'hv',
#     'code': '70501642',
#     'ids': ',hv70501642,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.003601,
#     'rms': 0.1,
#     'gap': 114,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 5km W of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.284668, 19.4221668, 0.93]},
#    'id': 'hv70501642'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.9,
#     'place': '26km S of Gardnerville Ranchos, Nevada',
#     'time': 1533022761329,
#     'updated': 1533063303586,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00647982',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00647982&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 12,
#     'net': 'nn',
#     'code': '00647982',
#     'ids': ',nn00647982,',
#     'sources': ',nn,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.276,
#     'rms': 0.0769,
#     'gap': 196.92,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 26km S of Gardnerville Ranchos, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.7371, 38.6501, 7.9]},
#    'id': 'nn00647982'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.22,
#     'place': '3km SW of Volcano, Hawaii',
#     'time': 1533022663060,
#     'updated': 1533023007020,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501637',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501637&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 76,
#     'net': 'hv',
#     'code': '70501637',
#     'ids': ',hv70501637,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.007985,
#     'rms': 0.23,
#     'gap': 105,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 3km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2584991, 19.4041672, 0.55]},
#    'id': 'hv70501637'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.27,
#     'place': '2km W of Volcano, Hawaii',
#     'time': 1533022189730,
#     'updated': 1533022531880,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501617',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501617&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 79,
#     'net': 'hv',
#     'code': '70501617',
#     'ids': ',hv70501617,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.0125,
#     'rms': 0.06,
#     'gap': 256,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 2km W of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2644958, 19.4266663, 2.41]},
#    'id': 'hv70501617'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.12,
#     'place': '12km ESE of Julian, CA',
#     'time': 1533022044480,
#     'updated': 1533044288492,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233936',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233936&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ci',
#     'code': '38233936',
#     'ids': ',ci38233936,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 34,
#     'dmin': 0.1052,
#     'rms': 0.21,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 12km ESE of Julian, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.4785, 33.0481667, 9.67]},
#    'id': 'ci38233936'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.21,
#     'place': '7km SW of Volcano, Hawaii',
#     'time': 1533022029620,
#     'updated': 1533022370150,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501612',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501612&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 75,
#     'net': 'hv',
#     'code': '70501612',
#     'ids': ',hv70501612,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.00391,
#     'rms': 0.15,
#     'gap': 69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 7km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2906647, 19.3876667, 0.3]},
#    'id': 'hv70501612'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.25,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533021940220,
#     'updated': 1533022282210,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501607',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501607&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 78,
#     'net': 'hv',
#     'code': '70501607',
#     'ids': ',hv70501607,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.003112,
#     'rms': 0.21,
#     'gap': 70,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.272171, 19.3981667, 1.07]},
#    'id': 'hv70501607'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.07,
#     'place': '2km E of Juana Diaz, Puerto Rico',
#     'time': 1533021921670,
#     'updated': 1533042553919,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2018212034',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2018212034&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 66,
#     'net': 'pr',
#     'code': '2018212034',
#     'ids': ',pr2018212034,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.0949,
#     'rms': 0.51,
#     'gap': 159,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 2km E of Juana Diaz, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.487, 18.0523, 18]},
#    'id': 'pr2018212034'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.66,
#     'place': '7km N of Fairport Harbor, Ohio',
#     'time': 1533021785070,
#     'updated': 1533059372970,
#     'tz': -300,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ld60061303',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ld60061303&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 42,
#     'net': 'ld',
#     'code': '60061303',
#     'ids': ',ld60061303,',
#     'sources': ',ld,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.2836,
#     'rms': 0.31,
#     'gap': 183,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 7km N of Fairport Harbor, Ohio'},
#    'geometry': {'type': 'Point', 'coordinates': [-81.2666667, 41.8161667, 5]},
#    'id': 'ld60061303'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.06,
#     'place': '5km WSW of Volcano, Hawaii',
#     'time': 1533021727570,
#     'updated': 1539704049040,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501602',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501602&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 144,
#     'net': 'hv',
#     'code': '70501602',
#     'ids': ',hv70501602,us2000ghz7,',
#     'sources': ',hv,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 48,
#     'dmin': 0.0116,
#     'rms': 0.29,
#     'gap': 26,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 5km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2870026, 19.4063339, 1.13]},
#    'id': 'hv70501602'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '6km SW of Volcano, Hawaii',
#     'time': 1533021701140,
#     'updated': 1533026062522,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501597',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501597&format=geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'hv',
#     'code': '70501597',
#     'ids': ',hv70501597,',
#     'sources': ',hv,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.009142,
#     'rms': 0.12,
#     'gap': 96,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 6km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2838287, 19.3955002, 0.28]},
#    'id': 'hv70501597'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.7,
#     'place': '34km ESE of Sutton-Alpine, Alaska',
#     'time': 1533021689854,
#     'updated': 1562004018432,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0189qq869l',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0189qq869l&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 8,
#     'net': 'ak',
#     'code': '0189qq869l',
#     'ids': ',ak19995379,ak0189qq869l,',
#     'sources': ',ak,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.5,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.7 - 34km ESE of Sutton-Alpine, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.2113, 61.7289, 9.6]},
#    'id': 'ak0189qq869l'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.88,
#     'place': '5km WSW of Volcano, Hawaii',
#     'time': 1533021586550,
#     'updated': 1533021926600,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501592',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501592&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 54,
#     'net': 'hv',
#     'code': '70501592',
#     'ids': ',hv70501592,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.01164,
#     'rms': 0.26,
#     'gap': 50,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 5km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2841644, 19.4090004, -0.22]},
#    'id': 'hv70501592'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.84,
#     'place': '3km W of Volcano, Hawaii',
#     'time': 1533021399770,
#     'updated': 1533021578740,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501572',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501572&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'hv',
#     'code': '70501572',
#     'ids': ',hv70501572,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.006106,
#     'rms': 0.15,
#     'gap': 122,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 3km W of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2725067, 19.4311676, -0.17]},
#    'id': 'hv70501572'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.95,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1533021386230,
#     'updated': 1533021728600,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501567',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501567&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 58,
#     'net': 'hv',
#     'code': '70501567',
#     'ids': ',hv70501567,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.005528,
#     'rms': 0.19,
#     'gap': 64,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2711639, 19.3903332, 0.56]},
#    'id': 'hv70501567'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.78,
#     'place': '3km WSW of Volcano, Hawaii',
#     'time': 1533021117590,
#     'updated': 1533021459450,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501557',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501557&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 49,
#     'net': 'hv',
#     'code': '70501557',
#     'ids': ',hv70501557,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.005039,
#     'rms': 0.08,
#     'gap': 110,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 3km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2624969, 19.4165001, 0.97]},
#    'id': 'hv70501557'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.93,
#     'place': '100km N of Road Town, British Virgin Islands',
#     'time': 1533021105470,
#     'updated': 1539704058040,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2018212031',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2018212031&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 132,
#     'net': 'pr',
#     'code': '2018212031',
#     'ids': ',pr2018212031,us2000gi5k,',
#     'sources': ',pr,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 4,
#     'dmin': 1.5098,
#     'rms': 0.15,
#     'gap': 341,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 100km N of Road Town, British Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.7836, 19.2121, 77]},
#    'id': 'pr2018212031'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.77,
#     'place': '9km W of Entiat, Washington',
#     'time': 1533021037960,
#     'updated': 1533263991140,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61414176',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61414176&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 9,
#     'net': 'uw',
#     'code': '61414176',
#     'ids': ',uw61414176,',
#     'sources': ',uw,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.1592,
#     'rms': 0.11,
#     'gap': 126,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 9km W of Entiat, Washington'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.3331667, 47.6723333, -0.01]},
#    'id': 'uw61414176'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.38,
#     'place': '2km WSW of Volcano, Hawaii',
#     'time': 1533020945570,
#     'updated': 1533021288000,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501547',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501547&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 87,
#     'net': 'hv',
#     'code': '70501547',
#     'ids': ',hv70501547,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 16,
#     'dmin': 0.00376,
#     'rms': 0.12,
#     'gap': 77,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 2km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2644958, 19.4213333, 0.65]},
#    'id': 'hv70501547'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.75,
#     'place': '6km W of Volcano, Hawaii',
#     'time': 1533020905980,
#     'updated': 1533021248270,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501542',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501542&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'hv',
#     'code': '70501542',
#     'ids': ',hv70501542,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.01149,
#     'rms': 0.19,
#     'gap': 122,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 6km W of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.3031616, 19.4190006, -0.64]},
#    'id': 'hv70501542'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.03,
#     'place': '8km WSW of Anza, CA',
#     'time': 1533020722900,
#     'updated': 1533044290927,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233920',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233920&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'ci',
#     'code': '38233920',
#     'ids': ',ci38233920,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.04263,
#     'rms': 0.05,
#     'gap': 96,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.0 - 8km WSW of Anza, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.7451667, 33.5231667, 4.52]},
#    'id': 'ci38233920'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.44,
#     'place': '5km WSW of Volcano, Hawaii',
#     'time': 1533020716920,
#     'updated': 1533021065210,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501537',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501537&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 92,
#     'net': 'hv',
#     'code': '70501537',
#     'ids': ',hv70501537,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.001186,
#     'rms': 0.25,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 5km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2843323, 19.4188328, 0.37]},
#    'id': 'hv70501537'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.13,
#     'place': '1km SW of Volcano, Hawaii',
#     'time': 1533020648770,
#     'updated': 1533020988340,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501527',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501527&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 70,
#     'net': 'hv',
#     'code': '70501527',
#     'ids': ',hv70501527,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.009583,
#     'rms': 0.18,
#     'gap': 146,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 1km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2514954, 19.4195004, 0.06]},
#    'id': 'hv70501527'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '15km NW of Sandy Valley, Nevada',
#     'time': 1533020630840,
#     'updated': 1533062931738,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00647978',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00647978&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nn',
#     'code': '00647978',
#     'ids': ',nn00647978,',
#     'sources': ',nn,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.282,
#     'rms': 0.1622,
#     'gap': 234.48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 15km NW of Sandy Valley, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.7566, 35.9097, 6.2]},
#    'id': 'nn00647978'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '245km SE of Kodiak, Alaska',
#     'time': 1533020608090,
#     'updated': 1562004017947,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000g4h1',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000g4h1&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 121,
#     'net': 'us',
#     'code': '1000g4h1',
#     'ids': ',ak20016621,us1000g4h1,ak0189qq4bhq,',
#     'sources': ',ak,us,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.257,
#     'rms': 0.52,
#     'gap': 190,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 245km SE of Kodiak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.6756, 56.1632, 21.35]},
#    'id': 'us1000g4h1'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.06,
#     'place': '4km SSW of Volcano, Hawaii',
#     'time': 1533020531330,
#     'updated': 1533020875000,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501517',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501517&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 65,
#     'net': 'hv',
#     'code': '70501517',
#     'ids': ',hv70501517,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.004523,
#     'rms': 0.21,
#     'gap': 96,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 4km SSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2613373, 19.3973331, 0.54]},
#    'id': 'hv70501517'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '247km SE of Kodiak, Alaska',
#     'time': 1533020479060,
#     'updated': 1562004017298,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000g4gz',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000g4gz&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'us',
#     'code': '1000g4gz',
#     'ids': ',ak20016620,us1000g4gz,ak0189qq3v9g,',
#     'sources': ',ak,us,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.274,
#     'rms': 0.68,
#     'gap': 211,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 247km SE of Kodiak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.6554, 56.1497, 21.3]},
#    'id': 'us1000g4gz'},
#   {'type': 'Feature',
#    'properties': {'mag': 3,
#     'place': '255km SE of Kodiak, Alaska',
#     'time': 1533020397310,
#     'updated': 1562004016823,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000g4gy',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000g4gy&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'us',
#     'code': '1000g4gy',
#     'ids': ',ak20016619,us1000g4gy,ak0189qq3lzw,',
#     'sources': ',ak,us,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.33,
#     'rms': 0.76,
#     'gap': 213,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 255km SE of Kodiak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.6247, 56.0678, 21.75]},
#    'id': 'us1000g4gy'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.49,
#     'place': '6km SW of Volcano, Hawaii',
#     'time': 1533020394890,
#     'updated': 1533020740950,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501512',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501512&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 95,
#     'net': 'hv',
#     'code': '70501512',
#     'ids': ',hv70501512,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.008015,
#     'rms': 0.09,
#     'gap': 73,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 6km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2856598, 19.3936672, 1.19]},
#    'id': 'hv70501512'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.25,
#     'place': '4km SW of Volcano, Hawaii',
#     'time': 1533020236300,
#     'updated': 1539704049040,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501507',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501507&format=geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 163,
#     'net': 'hv',
#     'code': '70501507',
#     'ids': ',hv70501507,us2000ghys,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': 50,
#     'dmin': 0.005348,
#     'rms': 0.32,
#     'gap': 33,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 4km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2709961, 19.4008331, 0.68]},
#    'id': 'hv70501507'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.1,
#     'place': '2km SW of Semisopochnoi Island, Alaska',
#     'time': 1533020202440,
#     'updated': 1551923791650,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av70797839',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av70797839&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'av',
#     'code': '70797839',
#     'ids': ',av70797839,',
#     'sources': ',av,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 4,
#     'dmin': None,
#     'rms': 0.26,
#     'gap': 172,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.1 - 2km SW of Semisopochnoi Island, Alaska'},
#    'geometry': {'type': 'Point',
#     'coordinates': [179.5708333, 51.9341667, 5.07]},
#    'id': 'av70797839'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.53,
#     'place': '3km W of Volcano, Hawaii',
#     'time': 1533020191720,
#     'updated': 1533020536480,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501502',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501502&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'hv',
#     'code': '70501502',
#     'ids': ',hv70501502,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.004222,
#     'rms': 0.17,
#     'gap': 74,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 3km W of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2718353, 19.4255009, 0.77]},
#    'id': 'hv70501502'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '122km N of Larsen Bay, Alaska',
#     'time': 1533020182179,
#     'updated': 1562004016240,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0189qpu84p',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0189qpu84p&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '0189qpu84p',
#     'ids': ',ak20016618,ak0189qpu84p,',
#     'sources': ',ak,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 122km N of Larsen Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.9734, 58.6429, 85.6]},
#    'id': 'ak0189qpu84p'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '90km WNW of Larsen Bay, Alaska',
#     'time': 1533020104988,
#     'updated': 1562004015785,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0189qptz36',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0189qptz36&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '0189qptz36',
#     'ids': ',ak20016617,ak0189qptz36,',
#     'sources': ',ak,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.39,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 90km WNW of Larsen Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.3872, 57.8325, 85.4]},
#    'id': 'ak0189qptz36'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.36,
#     'place': '3km SW of Volcano, Hawaii',
#     'time': 1533020011500,
#     'updated': 1533020351540,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501497',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501497&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 86,
#     'net': 'hv',
#     'code': '70501497',
#     'ids': ',hv70501497,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.001946,
#     'rms': 0.27,
#     'gap': 113,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 3km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2581635, 19.4109993, 0.31]},
#    'id': 'hv70501497'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.93,
#     'place': '1km SW of Volcano, Hawaii',
#     'time': 1533019964770,
#     'updated': 1533020305720,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501492',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501492&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 57,
#     'net': 'hv',
#     'code': '70501492',
#     'ids': ',hv70501492,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 11,
#     'dmin': 0.007361,
#     'rms': 0.1,
#     'gap': 144,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 1km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2534943, 19.4208336, 0.44]},
#    'id': 'hv70501492'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.52,
#     'place': '4km SW of Volcano, Hawaii',
#     'time': 1533019861280,
#     'updated': 1533020202240,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501487',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501487&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'hv',
#     'code': '70501487',
#     'ids': ',hv70501487,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 28,
#     'dmin': 0.002337,
#     'rms': 0.34,
#     'gap': 51,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 4km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2638397, 19.399334, -0.01]},
#    'id': 'hv70501487'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '251km SE of Kodiak, Alaska',
#     'time': 1533019809860,
#     'updated': 1562004015281,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000gib8',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000gib8&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'us',
#     'code': '2000gib8',
#     'ids': ',ak19998117,us2000gib8,ak0189qpsx0o,',
#     'sources': ',ak,us,ak,',
#     'types': ',associate,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.299,
#     'rms': 0.89,
#     'gap': 212,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 251km SE of Kodiak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.6527, 56.1024, 21.5]},
#    'id': 'us2000gib8'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.27,
#     'place': '2km WSW of Volcano, Hawaii',
#     'time': 1533019796240,
#     'updated': 1533020141810,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70501482',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70501482&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 79,
#     'net': 'hv',
#     'code': '70501482',
#     'ids': ',hv70501482,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.005384,
#     'rms': 0.13,
#     'gap': 159,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 2km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2578278, 19.4185009, 0.46]},
#    'id': 'hv70501482'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.2,
#     'place': '4km WSW of Mammoth Lakes, CA',
#     'time': 1533019784100,
#     'updated': 1533076763464,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73061801',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73061801&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'nc',
#     'code': '73061801',
#     'ids': ',nc73061801,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.007514,
#     'rms': 0.04,
#     'gap': 87,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M -0.2 - 4km WSW of Mammoth Lakes, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.018, 37.6198333, 0.43]},
#    'id': 'nc73061801'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.15,
#     'place': '1km WSW of Volcano, Hawaii',
#     'time': 1533019765570,
#     'updated': 1533020108100,
#     'tz': -600,
# ...
#     'updated': 1532959587970,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498057',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498057&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 60,
#     'net': 'hv',
#     'code': '70498057',
#     'ids': ',hv70498057,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.007709,
#     'rms': 0.27,
#     'gap': 54,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 3km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2680054, 19.4113331, 1.21]},
#    'id': 'hv70498057'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.06,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1532959023090,
#     'updated': 1532987979057,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498052',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498052&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 65,
#     'net': 'hv',
#     'code': '70498052',
#     'ids': ',hv70498052,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.003924,
#     'rms': 0.16,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2761688, 19.3985004, 1.26]},
#    'id': 'hv70498052'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.59,
#     'place': '6km WSW of Fern Acres, Hawaii',
#     'time': 1532958924440,
#     'updated': 1532987957677,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498042',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498042&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 103,
#     'net': 'hv',
#     'code': '70498042',
#     'ids': ',hv70498042,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.129,
#     'rms': 0.3,
#     'gap': 322,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 6km WSW of Fern Acres, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.1430054, 19.4925003, 4.53]},
#    'id': 'hv70498042'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.88,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1532958780730,
#     'updated': 1532987751347,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498037',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498037&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 128,
#     'net': 'hv',
#     'code': '70498037',
#     'ids': ',hv70498037,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 35,
#     'dmin': 0.007559,
#     'rms': 0.26,
#     'gap': 44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2666626, 19.390667, -0.13]},
#    'id': 'hv70498037'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.59,
#     'place': '4km WSW of Volcano, Hawaii',
#     'time': 1532958675330,
#     'updated': 1532959017090,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498032',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498032&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 103,
#     'net': 'hv',
#     'code': '70498032',
#     'ids': ',hv70498032,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 40,
#     'dmin': 0.00608,
#     'rms': 0.14,
#     'gap': 38,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 4km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2776642, 19.4173336, 2.07]},
#    'id': 'hv70498032'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.85,
#     'place': '1km NW of Lake Davis, CA',
#     'time': 1532958565740,
#     'updated': 1533174482750,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73060756',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73060756&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'nc',
#     'code': '73060756',
#     'ids': ',nn00647749,nc73060756,',
#     'sources': ',nn,nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.03713,
#     'rms': 0.03,
#     'gap': 85,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 1km NW of Lake Davis, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-120.4821667, 39.8745, 4.83]},
#    'id': 'nc73060756'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.06,
#     'place': '6km SW of Volcano, Hawaii',
#     'time': 1532958507960,
#     'updated': 1532958849440,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498022',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498022&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 65,
#     'net': 'hv',
#     'code': '70498022',
#     'ids': ',hv70498022,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.006352,
#     'rms': 0.18,
#     'gap': 57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 6km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2749939, 19.3868332, 1.06]},
#    'id': 'hv70498022'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.29,
#     'place': '5km SW of Volcano, Hawaii',
#     'time': 1532958134910,
#     'updated': 1532958477120,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70498002',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70498002&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 81,
#     'net': 'hv',
#     'code': '70498002',
#     'ids': ',hv70498002,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.006174,
#     'rms': 0.13,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 5km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2799988, 19.3968334, 0.87]},
#    'id': 'hv70498002'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.56,
#     'place': '6km WSW of Volcano, Hawaii',
#     'time': 1532958009630,
#     'updated': 1532958350300,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497997',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497997&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 101,
#     'net': 'hv',
#     'code': '70497997',
#     'ids': ',hv70497997,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 29,
#     'dmin': 0.009043,
#     'rms': 0.15,
#     'gap': 37,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 6km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2908325, 19.4039993, 0.25]},
#    'id': 'hv70497997'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.02,
#     'place': '3km SW of Volcano, Hawaii',
#     'time': 1532957917580,
#     'updated': 1532958257850,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497992',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497992&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 63,
#     'net': 'hv',
#     'code': '70497992',
#     'ids': ',hv70497992,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 23,
#     'dmin': 0.006134,
#     'rms': 0.12,
#     'gap': 42,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 3km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2655029, 19.4090004, 1.7]},
#    'id': 'hv70497992'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.41,
#     'place': '123km N of Hatillo, Puerto Rico',
#     'time': 1532957917130,
#     'updated': 1532959349665,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2018211006',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2018211006&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 179,
#     'net': 'pr',
#     'code': '2018211006',
#     'ids': ',pr2018211006,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 13,
#     'dmin': 1.1465,
#     'rms': 0.44,
#     'gap': 311,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 123km N of Hatillo, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.7463, 19.603, 66]},
#    'id': 'pr2018211006'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.2,
#     'place': '15km NE of Hawthorne, Nevada',
#     'time': 1532957898363,
#     'updated': 1533002718471,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00647784',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00647784&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nn',
#     'code': '00647784',
#     'ids': ',nn00647784,',
#     'sources': ',nn,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.014,
#     'rms': 0.0895,
#     'gap': 219.43,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.2 - 15km NE of Hawthorne, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.5225, 38.6422, 7.3]},
#    'id': 'nn00647784'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '139km SSW of Sibolga, Indonesia',
#     'time': 1532957668030,
#     'updated': 1539704052040,
#     'tz': 420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000gh6d',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000gh6d&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '2000gh6d',
#     'ids': ',us2000gh6d,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.983,
#     'rms': 0.96,
#     'gap': 75,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 139km SSW of Sibolga, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [98.2642, 0.5973, 35]},
#    'id': 'us2000gh6d'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.84,
#     'place': '4km WSW of Volcano, Hawaii',
#     'time': 1532957667040,
#     'updated': 1532958010740,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497977',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497977&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'hv',
#     'code': '70497977',
#     'ids': ',hv70497977,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 9,
#     'dmin': 0.008756,
#     'rms': 0.12,
#     'gap': 142,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 4km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2769928, 19.4120007, -0.05]},
#    'id': 'hv70497977'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.84,
#     'place': '4km WSW of Volcano, Hawaii',
#     'time': 1532957666270,
#     'updated': 1532958019360,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497982',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497982&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'hv',
#     'code': '70497982',
#     'ids': ',hv70497982,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.005316,
#     'rms': 0.12,
#     'gap': 50,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 4km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2801666, 19.4138336, 0.76]},
#    'id': 'hv70497982'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.74,
#     'place': '4km WSW of Volcano, Hawaii',
#     'time': 1532957584590,
#     'updated': 1532957924370,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497972',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497972&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 47,
#     'net': 'hv',
#     'code': '70497972',
#     'ids': ',hv70497972,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.01118,
#     'rms': 0.14,
#     'gap': 45,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 4km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2763367, 19.4091663, 0.45]},
#    'id': 'hv70497972'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.25,
#     'place': '2km WSW of Volcano, Hawaii',
#     'time': 1532957399540,
#     'updated': 1532957740940,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497967',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497967&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 78,
#     'net': 'hv',
#     'code': '70497967',
#     'ids': ',hv70497967,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.003525,
#     'rms': 0.18,
#     'gap': 134,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 2km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2611694, 19.4195004, 0.73]},
#    'id': 'hv70497967'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.09,
#     'place': '4km WSW of Volcano, Hawaii',
#     'time': 1532957292500,
#     'updated': 1532957632250,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv70497957',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv70497957&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 67,
#     'net': 'hv',
#     'code': '70497957',
#     'ids': ',hv70497957,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.009516,
#     'rms': 0.16,
#     'gap': 55,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 4km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2788391, 19.4095001, 0.65]},
#    'id': 'hv70497957'},
#   ...],
#  'bbox': [-179.8088, -60.8836, -3.15, 179.7994, 69.1675, 656.86]}

# %% [markdown]
# Alle Erbeben mit den ungefähren Koordinaten von Mexiko. [Hier könnte man die ungefähr nachschlagen.](http://www.latlong.net/)

# %%
urlloc = '&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85'

# %%
url1+urlzeit+urlloc
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85'

# %%
response = requests.get(url1+urlzeit+urlloc)
response.text
# Out:
# '{"type":"FeatureCollection","metadata":{"generated":1568993573000,"url":"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85","title":"USGS Earthquakes","status":200,"api":"1.8.1","count":7},"features":[{"type":"Feature","properties":{"mag":4.0999999999999996,"place":"19km NE of San Jeronimo Ixtepec, Mexico","time":1533010343830,"updated":1539704053040,"tz":-360,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson","felt":1,"cdi":2,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":259,"net":"us","code":"2000ghw0","ids":",us2000ghw0,","sources":",us,","types":",dyfi,geoserve,origin,phase-data,","nst":null,"dmin":2.7370000000000001,"rms":0.96999999999999997,"gap":161,"magType":"mb","type":"earthquake","title":"M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico"},"geometry":{"type":"Point","coordinates":[-94.958699999999993,16.687999999999999,73.310000000000002]},"id":"us2000ghw0"},\n{"type":"Feature","properties":{"mag":1.8600000000000001,"place":"34km NE of Ensenada, B.C., MX","time":1533008835490,"updated":1533058052742,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233848","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233848&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":53,"net":"ci","code":"38233848","ids":",ci38233848,","sources":",ci,","types":",geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":20,"dmin":0.30030000000000001,"rms":0.20000000000000001,"gap":169,"magType":"ml","type":"earthquake","title":"M 1.9 - 34km NE of Ensenada, B.C., MX"},"geometry":{"type":"Point","coordinates":[-116.399,32.112833299999998,16.030000000000001]},"id":"ci38233848"},\n{"type":"Feature","properties":{"mag":1.8500000000000001,"place":"9km W of Progreso, B.C., MX","time":1532977028010,"updated":1533060562548,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233408","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233408&format=geojson","felt":1,"cdi":3.1000000000000001,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":53,"net":"ci","code":"38233408","ids":",ci38233408,","sources":",ci,","types":",dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":26,"dmin":0.085019999999999998,"rms":0.22,"gap":87,"magType":"ml","type":"earthquake","title":"M 1.9 - 9km W of Progreso, B.C., MX"},"geometry":{"type":"Point","coordinates":[-115.6803333,32.573500000000003,9.9199999999999999]},"id":"ci38233408"},\n{"type":"Feature","properties":{"mag":1.8200000000000001,"place":"26km ENE of Pine Valley, CA","time":1532964179630,"updated":1532965631270,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233160","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233160&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":51,"net":"ci","code":"38233160","ids":",ci38233160,","sources":",ci,","types":",focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,","nst":38,"dmin":0.13109999999999999,"rms":0.20999999999999999,"gap":67,"magType":"ml","type":"earthquake","title":"M 1.8 - 26km ENE of Pine Valley, CA"},"geometry":{"type":"Point","coordinates":[-116.26649999999999,32.889000000000003,6.8899999999999997]},"id":"ci38233160"},\n{"type":"Feature","properties":{"mag":1.8600000000000001,"place":"6km WSW of Holtville, CA","time":1532953778000,"updated":1533051921620,"tz":-480,"url":"https://earthquake.usgs.gov/earthquakes/eventpage/ci38233112","detail":"https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233112&format=geojson","felt":null,"cdi":null,"mmi":null,"alert":null,"status":"reviewed","tsunami":0,"sig":53,"net":"ci","code":" ...

# %% [markdown]
# Dieser Wulst lässt sich aber ziemlich schwer lesen. Deshalb müssen wir das zuerst umformatieren und dann verstehen, wie das ganze strukturiert ist.

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1568993573000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-07-29T24:00:00&endtime=2018-07-31T08:00:00&minlatitude=13&maxlatitude=33&minlongitude=-120&maxlongitude=-85',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.8.1',
#   'count': 7},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#     'time': 1533010343830,
#     'updated': 1539704053040,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '2000ghw0',
#     'ids': ',us2000ghw0,',
#     'sources': ',us,',
#     'types': ',dyfi,geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 2.737,
#     'rms': 0.97,
#     'gap': 161,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#    'id': 'us2000ghw0'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.86,
#     'place': '34km NE of Ensenada, B.C., MX',
#     'time': 1533008835490,
#     'updated': 1533058052742,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233848',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233848&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'ci',
#     'code': '38233848',
#     'ids': ',ci38233848,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 20,
#     'dmin': 0.3003,
#     'rms': 0.2,
#     'gap': 169,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 34km NE of Ensenada, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.399, 32.1128333, 16.03]},
#    'id': 'ci38233848'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.85,
#     'place': '9km W of Progreso, B.C., MX',
#     'time': 1532977028010,
#     'updated': 1533060562548,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233408',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233408&format=geojson',
#     'felt': 1,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'ci',
#     'code': '38233408',
#     'ids': ',ci38233408,',
#     'sources': ',ci,',
#     'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 26,
#     'dmin': 0.08502,
#     'rms': 0.22,
#     'gap': 87,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 9km W of Progreso, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.6803333, 32.5735, 9.92]},
#    'id': 'ci38233408'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.82,
#     'place': '26km ENE of Pine Valley, CA',
#     'time': 1532964179630,
#     'updated': 1532965631270,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233160',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233160&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 51,
#     'net': 'ci',
#     'code': '38233160',
#     'ids': ',ci38233160,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 38,
#     'dmin': 0.1311,
#     'rms': 0.21,
#     'gap': 67,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 26km ENE of Pine Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.2665, 32.889, 6.89]},
#    'id': 'ci38233160'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.86,
#     'place': '6km WSW of Holtville, CA',
#     'time': 1532953778000,
#     'updated': 1533051921620,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233112',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233112&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'ci',
#     'code': '38233112',
#     'ids': ',ci38233112,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 34,
#     'dmin': 0.01344,
#     'rms': 0.22,
#     'gap': 33,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 6km WSW of Holtville, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.4395, 32.7933333, 11.89]},
#    'id': 'ci38233112'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.67,
#     'place': '70km WSW of Alberto Oviedo Mota, B.C., MX',
#     'time': 1532941201800,
#     'updated': 1532974980642,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37408933',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37408933&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 43,
#     'net': 'ci',
#     'code': '37408933',
#     'ids': ',ci37408933,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.1601,
#     'rms': 0.22,
#     'gap': 172,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 70km WSW of Alberto Oviedo Mota, B.C., MX'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.8056667, 31.8996667, 7.06]},
#    'id': 'ci37408933'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.79,
#     'place': '72km WSW of Alberto Oviedo Mota, B.C., MX',
#     'time': 1532931837280,
#     'updated': 1533049838920,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233000',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233000&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 120,
#     'net': 'ci',
#     'code': '38233000',
#     'ids': ',ci38233000,',
#     'sources': ',ci,',
#     'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.1449,
#     'rms': 0.22,
#     'gap': 118,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 72km WSW of Alberto Oviedo Mota, B.C., MX'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.8281667, 31.9015, 8.26]},
#    'id': 'ci38233000'}],
#  'bbox': [-116.399, 16.688, 6.89, -94.9587, 32.889, 73.31]}

# %%
dct = response.json()

# %% [markdown]
# Um sicher zu gehen, prüfen wir nochmals den Datentyp.

# %%
type(dct)
# Out:
# dict

# %%
len(dct)
# Out:
# 4

# %% [markdown]
# Schauen wir uns alle keys und values an

# %%
for key in dct:
    print(key)
# Out:
# type
# metadata
# features
# bbox

# %% [markdown]
# Features interessiert uns.

# %%
dct['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 4.1,
#    'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#    'time': 1533010343830,
#    'updated': 1539704053040,
#    'tz': -360,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 259,
#    'net': 'us',
#    'code': '2000ghw0',
#    'ids': ',us2000ghw0,',
#    'sources': ',us,',
#    'types': ',dyfi,geoserve,origin,phase-data,',
#    'nst': None,
#    'dmin': 2.737,
#    'rms': 0.97,
#    'gap': 161,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#   'id': 'us2000ghw0'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.86,
#    'place': '34km NE of Ensenada, B.C., MX',
#    'time': 1533008835490,
#    'updated': 1533058052742,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233848',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233848&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'ci',
#    'code': '38233848',
#    'ids': ',ci38233848,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 20,
#    'dmin': 0.3003,
#    'rms': 0.2,
#    'gap': 169,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 34km NE of Ensenada, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.399, 32.1128333, 16.03]},
#   'id': 'ci38233848'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.85,
#    'place': '9km W of Progreso, B.C., MX',
#    'time': 1532977028010,
#    'updated': 1533060562548,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233408',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233408&format=geojson',
#    'felt': 1,
#    'cdi': 3.1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'ci',
#    'code': '38233408',
#    'ids': ',ci38233408,',
#    'sources': ',ci,',
#    'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 26,
#    'dmin': 0.08502,
#    'rms': 0.22,
#    'gap': 87,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 9km W of Progreso, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.6803333, 32.5735, 9.92]},
#   'id': 'ci38233408'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.82,
#    'place': '26km ENE of Pine Valley, CA',
#    'time': 1532964179630,
#    'updated': 1532965631270,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233160',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233160&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 51,
#    'net': 'ci',
#    'code': '38233160',
#    'ids': ',ci38233160,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 38,
#    'dmin': 0.1311,
#    'rms': 0.21,
#    'gap': 67,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 26km ENE of Pine Valley, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2665, 32.889, 6.89]},
#   'id': 'ci38233160'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.86,
#    'place': '6km WSW of Holtville, CA',
#    'time': 1532953778000,
#    'updated': 1533051921620,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233112',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233112&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'ci',
#    'code': '38233112',
#    'ids': ',ci38233112,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 34,
#    'dmin': 0.01344,
#    'rms': 0.22,
#    'gap': 33,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 6km WSW of Holtville, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.4395, 32.7933333, 11.89]},
#   'id': 'ci38233112'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.67,
#    'place': '70km WSW of Alberto Oviedo Mota, B.C., MX',
#    'time': 1532941201800,
#    'updated': 1532974980642,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci37408933',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci37408933&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 43,
#    'net': 'ci',
#    'code': '37408933',
#    'ids': ',ci37408933,',
#    'sources': ',ci,',
#    'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.1601,
#    'rms': 0.22,
#    'gap': 172,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 70km WSW of Alberto Oviedo Mota, B.C., MX'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.8056667, 31.8996667, 7.06]},
#   'id': 'ci37408933'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.79,
#    'place': '72km WSW of Alberto Oviedo Mota, B.C., MX',
#    'time': 1532931837280,
#    'updated': 1533049838920,
#    'tz': -480,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci38233000',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci38233000&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 120,
#    'net': 'ci',
#    'code': '38233000',
#    'ids': ',ci38233000,',
#    'sources': ',ci,',
#    'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.1449,
#    'rms': 0.22,
#    'gap': 118,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 72km WSW of Alberto Oviedo Mota, B.C., MX'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.8281667, 31.9015, 8.26]},
#   'id': 'ci38233000'}]

# %%
type(dct['features'])
# Out:
# list

# %%
dct['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.1,
#   'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#   'time': 1533010343830,
#   'updated': 1539704053040,
#   'tz': -360,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#   'felt': 1,
#   'cdi': 2,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 259,
#   'net': 'us',
#   'code': '2000ghw0',
#   'ids': ',us2000ghw0,',
#   'sources': ',us,',
#   'types': ',dyfi,geoserve,origin,phase-data,',
#   'nst': None,
#   'dmin': 2.737,
#   'rms': 0.97,
#   'gap': 161,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#  'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#  'id': 'us2000ghw0'}

# %%
dct['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'mag': 4.1,
#   'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#   'time': 1533010343830,
#   'updated': 1539704053040,
#   'tz': -360,
#   'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#   'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#   'felt': 1,
#   'cdi': 2,
#   'mmi': None,
#   'alert': None,
#   'status': 'reviewed',
#   'tsunami': 0,
#   'sig': 259,
#   'net': 'us',
#   'code': '2000ghw0',
#   'ids': ',us2000ghw0,',
#   'sources': ',us,',
#   'types': ',dyfi,geoserve,origin,phase-data,',
#   'nst': None,
#   'dmin': 2.737,
#   'rms': 0.97,
#   'gap': 161,
#   'magType': 'mb',
#   'type': 'earthquake',
#   'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'},
#  'geometry': {'type': 'Point', 'coordinates': [-94.9587, 16.688, 73.31]},
#  'id': 'us2000ghw0'}

# %% [markdown]
# Schauen wir uns das erste Element an

# %%
for key in dct['features'][0]:
    print(key)
# Out:
# type
# properties
# geometry
# id

# %%
dct['features'][0]['properties']
# Out:
# {'mag': 4.1,
#  'place': '19km NE of San Jeronimo Ixtepec, Mexico',
#  'time': 1533010343830,
#  'updated': 1539704053040,
#  'tz': -360,
#  'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000ghw0',
#  'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000ghw0&format=geojson',
#  'felt': 1,
#  'cdi': 2,
#  'mmi': None,
#  'alert': None,
#  'status': 'reviewed',
#  'tsunami': 0,
#  'sig': 259,
#  'net': 'us',
#  'code': '2000ghw0',
#  'ids': ',us2000ghw0,',
#  'sources': ',us,',
#  'types': ',dyfi,geoserve,origin,phase-data,',
#  'nst': None,
#  'dmin': 2.737,
#  'rms': 0.97,
#  'gap': 161,
#  'magType': 'mb',
#  'type': 'earthquake',
#  'title': 'M 4.1 - 19km NE of San Jeronimo Ixtepec, Mexico'}

# %% [markdown]
# Lesen wir folgendes aus:
# 1. Type
# 2. Magnitude
# 4. Örtlichkeit
# 5. Time

# %%
earthquakes = []

for elem in dct['features']:
    
    t = elem['properties']['type']
    m = elem['properties']['mag']
    p = elem['properties']['place']
    tm = elem['properties']['time']
    
    mini_dict = {'Type': t,
                 'Mag': m,
                 'Place': p,
                 'Time': tm}
    
    earthquakes.append(mini_dict)

# %%
earthquakes[:3]
# Out:
# [{'Type': 'earthquake',
#   'Mag': 4.1,
#   'Place': '19km NE of San Jeronimo Ixtepec, Mexico',
#   'Time': 1533010343830},
#  {'Type': 'earthquake',
#   'Mag': 1.86,
#   'Place': '34km NE of Ensenada, B.C., MX',
#   'Time': 1533008835490},
#  {'Type': 'earthquake',
#   'Mag': 1.85,
#   'Place': '9km W of Progreso, B.C., MX',
#   'Time': 1532977028010}]

# %% [markdown]
# ### Erste Erfahrung mit Pandas

# %%
pd.DataFrame(earthquakes)
# Out:
#          Type   Mag                                      Place        Time
# 0  earthquake  4.10    19km NE of San Jeronimo Ixtepec, Mexico  1533010343
# 1  earthquake  1.86              34km NE of Ensenada, B.C., MX  1533008835
# 2  earthquake  1.85                9km W of Progreso, B.C., MX  1532977028
# 3  earthquake  1.82                26km ENE of Pine Valley, CA  1532964179
# 4  earthquake  1.86                   6km WSW of Holtville, CA  1532953778
# 5  earthquake  1.67  70km WSW of Alberto Oviedo Mota, B.C., MX  1532941201
# 6  earthquake  2.79  72km WSW of Alberto Oviedo Mota, B.C., MX  1532931837

# %%
df = pd.DataFrame(earthquakes)

# %% [markdown]
# Speichern wir das ab.

# %%
df.to_csv('erdbeben.csv')

# %% [markdown]
# # Üben wir das Ganze! Weiter zur Übung 1.
