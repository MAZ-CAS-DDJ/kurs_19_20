# %% [markdown]
# # Regex in Pandas

# %% [markdown]
# **Inhalt:** Regular Expressions in Pandas anwenden
#
# **Nötige Skills:** Regex in Python
#
# **Lernziele:**
# - Ein praktisches Beispiel kennenlernen, wo Regex nützlich sein kann

# %% [markdown]
# # Das Beispiel

# %% [markdown]
# Das Bundesamt für Statistik stellt oft Dateien in verknorkster Form zur Verfügung, zum Beispiel, wenn man Auswertungen nach Gemeinden, Bezirken und Kantonen über das interaktive Portal generieren lässt: https://www.pxweb.bfs.admin.ch/pxweb/de/
#
# Das vorliegende Beispiel beinhaltet die Bevölkerungszahlen, gegliedert nach Zivilstand einerseits (ledig, verheiratet, etc) und nach räumlicher Struktur (Gemeinden, Kantone, etc) andererseits.
#
# Das File ist gespeichert unter `dataprojects/BFS/px-x-0102010000_103.xlsx`

# %% [markdown]
# ## Vorbereitung

# %%
import pandas as pd

# %% [markdown]
# ## Datei laden

# %%
path = 'dataprojects/BFS/px-x-0102010000_103.xlsx'

# %%
df = pd.read_excel(path)

# %% [markdown]
# ## Explorieren

# %%
df.head(20)
# Out:
#                           Einheit           Bevölkerungstyp  \
# 0                         Schweiz  Ständige Wohnbevölkerung
# 1                         Schweiz  Ständige Wohnbevölkerung
# 2                         Schweiz  Ständige Wohnbevölkerung
# 3                         Schweiz  Ständige Wohnbevölkerung
# 4                        - Zürich  Ständige Wohnbevölkerung
# 5                        - Zürich  Ständige Wohnbevölkerung
# 6                        - Zürich  Ständige Wohnbevölkerung
# 7                        - Zürich  Ständige Wohnbevölkerung
# 8             >> Bezirk Affoltern  Ständige Wohnbevölkerung
# 9             >> Bezirk Affoltern  Ständige Wohnbevölkerung
# 10            >> Bezirk Affoltern  Ständige Wohnbevölkerung
# 11            >> Bezirk Affoltern  Ständige Wohnbevölkerung
# 12     ......0001 Aeugst am Albis  Ständige Wohnbevölkerung
# 13     ......0001 Aeugst am Albis  Ständige Wohnbevölkerung
# 14     ......0001 Aeugst am Albis  Ständige Wohnbevölkerung
# 15     ......0001 Aeugst am Albis  Ständige Wohnbevölkerung
# 16  ......0002 Affoltern am Albis  Ständige Wohnbevölkerung
# 17  ......0002 Affoltern am Albis  Ständige Wohnbevölkerung
# 18  ......0002 Affoltern am Albis  Ständige Wohnbevölkerung
# 19  ......0002 Affoltern am Albis  Ständige Wohnbevölkerung
#
#             Geschlecht                                         Zivilstand  \
# 0   Geschlecht - Total                                              Ledig
# 1   Geschlecht - Total        Verheiratet, in eingetragener Partnerschaft
# 2   Geschlecht - Total      Verwitwet, durch Tod aufgelöste Partnerschaft
# 3   Geschlecht - Total  Geschieden, unverheiratet, gerichtlich aufgelö...
# 4   Geschlecht - Total                                              Ledig
# 5   Geschlecht - Total        Verheiratet, in eingetragener Partnerschaft
# 6   Geschlecht - Total      Verwitwet, durch Tod aufgelöste Partnerschaft
# 7   Geschlecht - Total  Geschieden, unverheiratet, gerichtlich aufgelö...
# 8   Geschlecht - Total                                              Ledig
# 9   Geschlecht - Total        Verheiratet, in eingetragener Partnerschaft
# 10  Geschlecht - Total      Verwitwet, durch Tod aufgelöste Partnerschaft
# 11  Geschlecht - Total  Geschieden, unverheiratet, gerichtlich aufgelö...
# 12  Geschlecht - Total                                              Ledig
# 13  Geschlecht - Total        Verheiratet, in eingetragener Partnerschaft
# 14  Geschlecht - Total      Verwitwet, durch Tod aufgelöste Partnerschaft
# 15  Geschlecht - Total  Geschieden, unverheiratet, gerichtlich aufgelö...
# 16  Geschlecht - Total                                              Ledig
# 17  Geschlecht - Total        Verheiratet, in eingetragener Partnerschaft
# 18  Geschlecht - Total      Verwitwet, durch Tod aufgelöste Partnerschaft
# 19  Geschlecht - Total  Geschieden, unverheiratet, gerichtlich aufgelö...
#
#     Altersklasse - Total
# 0                3650651
# 1                3583008
# 2                 407408
# 3                 685622
# 4                 666873
# 5                 610396
# 6                  63173
# 7                 125889
# 8                  21785
# 9                  23865
# 10                  1875
# 11                  4076
# 12                   852
# 13                   908
# 14                    74
# 15                   147
# 16                  5000
# 17                  5159
# 18                   545
# 19                  1004

# %% [markdown]
# Offensichtlich müssen wir die Tabelle zuerst etwas umstellen, damit sie angenehm zu bearbeiten ist.
#
# ## Aufbereiten
#
# Wir möchten:
# - für jede Gemeinde, Bezirk eine Zeile
# - für jeden Zivilstand eine Spalte

# %% [markdown]
# Die Lösung dafür kennen wir bereits: `df.pivot()`

# %%
df = df.pivot(index='Einheit', columns='Zivilstand', values='Altersklasse - Total')

# %%
df.head(2)
# Out:
# Zivilstand                Geschieden, unverheiratet, gerichtlich aufgelöste Partnerschaft  \
# Einheit
# - Aargau                                                              50715
# - Appenzell Ausserrhoden                                               4496
#
# Zivilstand                 Ledig  Verheiratet, in eingetragener Partnerschaft  \
# Einheit
# - Aargau                  276123                                       296940
# - Appenzell Ausserrhoden   23055                                        24117
#
# Zivilstand                Verwitwet, durch Tod aufgelöste Partnerschaft
# Einheit
# - Aargau                                                          29873
# - Appenzell Ausserrhoden                                           2875

# %% [markdown]
# Nun verschönern wir die Sache noch etwas...

# %%
df = df.reset_index()

# %%
df.columns.name = None

# %%
spalten = {
    'Geschieden, unverheiratet, gerichtlich aufgelöste Partnerschaft': 'Geschieden',
    'Verheiratet, in eingetragener Partnerschaft': 'Verheiratet',
    'Verwitwet, durch Tod aufgelöste Partnerschaft': 'Verwitwet'
}

# %%
df = df.rename(columns=spalten)

# %%
df.head(2)
# Out:
#                     Einheit  Geschieden   Ledig  Verheiratet  Verwitwet
# 0                  - Aargau       50715  276123       296940      29873
# 1  - Appenzell Ausserrhoden        4496   23055        24117       2875

# %% [markdown]
# ## Die grographischen Einheiten...

# %% [markdown]
# Schauen wir uns mal näher an, was in der Spalte "Einheit" drinsteht

# %%
df['Einheit']
# Out:
# 0                                           - Aargau
# 1                           - Appenzell Ausserrhoden
# 2                            - Appenzell Innerrhoden
# 3                                 - Basel-Landschaft
# 4                                      - Basel-Stadt
# 5                                     - Bern / Berne
# 6                              - Fribourg / Freiburg
# 7                                           - Genève
# 8                                           - Glarus
# 9                 - Graubünden / Grigioni / Grischun
# 10                                            - Jura
# 11                                          - Luzern
# 12                                       - Neuchâtel
# 13                                       - Nidwalden
# 14                                        - Obwalden
# 15                                    - Schaffhausen
# 16                                          - Schwyz
# 17                                       - Solothurn
# 18                                      - St. Gallen
# 19                                         - Thurgau
# 20                                          - Ticino
# 21                                             - Uri
# 22                                 - Valais / Wallis
# 23                                            - Vaud
# 24                                             - Zug
# 25                                          - Zürich
# 26                        ......0001 Aeugst am Albis
# 27                     ......0002 Affoltern am Albis
# 28                             ......0003 Bonstetten
# 29                        ......0004 Hausen am Albis
#                             ...
# 2469                           >> Kanton Basel-Stadt
# 2470                                >> Kanton Glarus
# 2471                             >> Kanton Nidwalden
# 2472                              >> Kanton Obwalden
# 2473                                   >> Kanton Uri
# 2474                                   >> Kanton Zug
# 2475             >> Verwaltungskreis Bern-Mittelland
# 2476                 >> Verwaltungskreis Biel/Bienne
# 2477                    >> Verwaltungskreis Emmental
# 2478    >> Verwaltungskreis Frutigen-Niedersimmental
# 2479        >> Verwaltungskreis Interlaken-Oberhasli
# 2480                  >> Verwaltungskreis Oberaargau
# 2481        >> Verwaltungskreis Obersimmental-Saanen
# 2482                     >> Verwaltungskreis Seeland
# 2483                        >> Verwaltungskreis Thun
# 2484                          >> Wahlkreis Entlebuch
# 2485                           >> Wahlkreis Hochdorf
# 2486                        >> Wahlkreis Luzern-Land
# 2487                       >> Wahlkreis Luzern-Stadt
# 2488                           >> Wahlkreis Rheintal
# 2489                          >> Wahlkreis Rorschach
# 2490                      >> Wahlkreis Sarganserland
# 2491                         >> Wahlkreis See-Gaster
# 2492                         >> Wahlkreis St. Gallen
# 2493                             >> Wahlkreis Sursee
# 2494                         >> Wahlkreis Toggenburg
# 2495                         >> Wahlkreis Werdenberg
# 2496                                >> Wahlkreis Wil
# 2497                           >> Wahlkreis Willisau
# 2498                                         Schweiz
# Name: Einheit, Length: 2499, dtype: object

# %% [markdown]
# Welche Einheitstypen gibt es? Und welches Muster haben sie?
# - Gemeinde ("...... 9999 Gemeindename")
# - Bezirk (">> Bezirsname")
# - Kantone ("- Kantonsname")
# - Land ("Land")

# %% [markdown]
# Ziel:
# - eine Spalte "Einheitstyp"
# - eine Spalte "Einheitsnummer"
# - eine Spalte "Einheitsname"

# %% [markdown]
# ## Pandas-Funktionen, die Regex brauchen können

# %% [markdown]
# Einige Befehle heissen leicht anders, funktionieren aber sehr ähnlich wie in der re.Library
#
# - **`str.contains(r"regex")`**: das Pendant zu `re.search()` - ja/nein-Antwort
#
# - **`str.extract(r"regex")`**: auch ähnlich wie `re.search()` - Suchergebnis als Antwort
#
# - **`str.replace(r"regex", "str")`**: das Pendant zu `re.sub()` - ersetzt Match mit String

# %% [markdown]
# Wir wenden diese Funktionen jetzt an.

# %% [markdown]
# ### Aber zuerst ...

# %% [markdown]
# Zuerst brauchen wir die Regex-Ausdrücke, um die Einheiten zu erkennen. Am besten mit Tests beginnen, ob die Regex an einer Einheit anschlägt - und jeweils auch testen, ob die Regex bei Einheiten, die wir *nicht* wollen, auch *nicht* anschlägt.

# %%
# Test für Gemeinde
re.search(r"^\.{6}\d{4} .+$", "......0001 Aeugst am Albis")
# Out:
# <_sre.SRE_Match object; span=(0, 26), match='......0001 Aeugst am Albis'>

# %%
# Test für Bezirke
re.search(r"^>> .+$", ">> Wahlkreis Luzern-Stadt")
# Out:
# <_sre.SRE_Match object; span=(0, 25), match='>> Wahlkreis Luzern-Stadt'>

# %%
# Test für Kantone
re.search(r"^- .+$", "- Aargau")
# Out:
# <_sre.SRE_Match object; span=(0, 8), match='- Aargau'>

# %%
# Test für Land
re.search(r"Schweiz", "Schweiz")
# Out:
# <_sre.SRE_Match object; span=(0, 7), match='Schweiz'>

# %% [markdown]
# ### Spalte "Einheitstyp"

# %% [markdown]
# Hier können wir die Funktion `str.contains()` gut brauchen.
#
# Wir testen damit mal, ob die Einträge in der Spalte "Einheit" eine Gemeinde sind:

# %%
df['Einheit'].str.contains(r"^\.{6}\d{4} .+$")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 2469    False
# 2470    False
# 2471    False
# 2472    False
# 2473    False
# 2474    False
# 2475    False
# 2476    False
# 2477    False
# 2478    False
# 2479    False
# 2480    False
# 2481    False
# 2482    False
# 2483    False
# 2484    False
# 2485    False
# 2486    False
# 2487    False
# 2488    False
# 2489    False
# 2490    False
# 2491    False
# 2492    False
# 2493    False
# 2494    False
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# Name: Einheit, Length: 2499, dtype: bool

# %% [markdown]
# Basierend auf dieser True/False-Liste können wir nun die Tabelle filtern und mit `df.loc[]` jeweils den richtigen Eintrag in unserer neuen Spalte "Einheitstyp" erzeugen.

# %%
df.loc[df['Einheit'].str.contains(r"^\.{6}\d{4} .+$"), 'Einheitstyp'] = "Gemeinde"
df.loc[df['Einheit'].str.contains(r"^>> .+$"), 'Einheitstyp'] = "Bezirk"
df.loc[df['Einheit'].str.contains(r"^- .+$"), 'Einheitstyp'] = "Kanton"
df.loc[df['Einheit'].str.contains(r"Schweiz"), 'Einheitstyp'] = "Land"

# %%
df
# Out:
#                                            Einheit  Geschieden    Ledig  \
# 0                                         - Aargau       50715   276123
# 1                         - Appenzell Ausserrhoden        4496    23055
# 2                          - Appenzell Innerrhoden         814     7338
# 3                               - Basel-Landschaft       22994   113105
# 4                                    - Basel-Stadt       18693    89611
# 5                                   - Bern / Berne       84364   437186
# 6                            - Fribourg / Freiburg       23511   138940
# 7                                         - Genève       46072   224586
# 8                                         - Glarus        3066    16607
# 9               - Graubünden / Grigioni / Grischun       14957    83298
# 10                                          - Jura        5786    31049
# 11                                        - Luzern       26541   181455
# 12                                     - Neuchâtel       17812    77637
# 13                                     - Nidwalden        3176    18392
# 14                                      - Obwalden        2311    16432
# 15                                  - Schaffhausen        6819    32404
# 16                                        - Schwyz       11639    66828
# 17                                     - Solothurn       22767   110681
# 18                                    - St. Gallen       39145   215628
# 19                                       - Thurgau       22240   113225
# 20                                        - Ticino       28986   146039
# 21                                           - Uri        1751    15323
# 22                               - Valais / Wallis       26205   142216
# 23                                          - Vaud       65726   353300
# 24                                           - Zug        9147    53320
# 25                                        - Zürich      125889   666873
# 26                      ......0001 Aeugst am Albis         147      852
# 27                   ......0002 Affoltern am Albis        1004     5000
# 28                           ......0003 Bonstetten         383     2336
# 29                      ......0004 Hausen am Albis         317     1433
# ...                                            ...         ...      ...
# 2469                         >> Kanton Basel-Stadt       18693    89611
# 2470                              >> Kanton Glarus        3066    16607
# 2471                           >> Kanton Nidwalden        3176    18392
# 2472                            >> Kanton Obwalden        2311    16432
# 2473                                 >> Kanton Uri        1751    15323
# 2474                                 >> Kanton Zug        9147    53320
# 2475           >> Verwaltungskreis Bern-Mittelland       33777   182532
# 2476               >> Verwaltungskreis Biel/Bienne       10231    42596
# 2477                  >> Verwaltungskreis Emmental        6777    40831
# 2478  >> Verwaltungskreis Frutigen-Niedersimmental        2889    16112
# 2479      >> Verwaltungskreis Interlaken-Oberhasli        3944    19446
# 2480                >> Verwaltungskreis Oberaargau        6296    33065
# 2481      >> Verwaltungskreis Obersimmental-Saanen        1010     6845
# 2482                   >> Verwaltungskreis Seeland        5750    29711
# 2483                      >> Verwaltungskreis Thun        9126    43818
# 2484                        >> Wahlkreis Entlebuch         895    10905
# 2485                         >> Wahlkreis Hochdorf        4725    31103
# 2486                      >> Wahlkreis Luzern-Land        7313    42142
# 2487                     >> Wahlkreis Luzern-Stadt        7006    40545
# 2488                         >> Wahlkreis Rheintal        5535    30340
# 2489                        >> Wahlkreis Rorschach        3837    17237
# 2490                    >> Wahlkreis Sarganserland        2898    16975
# 2491                       >> Wahlkreis See-Gaster        4970    27714
# 2492                       >> Wahlkreis St. Gallen       10213    55644
# 2493                           >> Wahlkreis Sursee        3863    32943
# 2494                       >> Wahlkreis Toggenburg        3198    19559
# 2495                       >> Wahlkreis Werdenberg        3035    16152
# 2496                              >> Wahlkreis Wil        5459    32007
# 2497                         >> Wahlkreis Willisau        2739    23817
# 2498                                       Schweiz      685622  3650651
#
#       Verheiratet  Verwitwet Einheitstyp
# 0          296940      29873      Kanton
# 1           24117       2875      Kanton
# 2            6971        851      Kanton
# 3          131580      15539      Kanton
# 4           72481      11023      Kanton
# 5          439372      56513      Kanton
# 6          131592      13403      Kanton
# 7          193557      20496      Kanton
# 8           18015       2338      Kanton
# 9           87623      10724      Kanton
# 10          31408       4538      Kanton
# 11         172144      18613      Kanton
# 12          72766       9890      Kanton
# 13          18905       1946      Kanton
# 14          16562       1771      Kanton
# 15          35972       4638      Kanton
# 16          68701       6920      Kanton
# 17         118459      14499      Kanton
# 18         219912      24365      Kanton
# 19         119530      12428      Kanton
# 20         155489      21428      Kanton
# 21          16871       2027      Kanton
# 22         149122      18131      Kanton
# 23         319635      34632      Kanton
# 24          54888       4774      Kanton
# 25         610396      63173      Kanton
# 26            908         74    Gemeinde
# 27           5159        545    Gemeinde
# 28           2452        154    Gemeinde
# 29           1596        131    Gemeinde
# ...           ...        ...         ...
# 2469        72481      11023      Bezirk
# 2470        18015       2338      Bezirk
# 2471        18905       1946      Bezirk
# 2472        16562       1771      Bezirk
# 2473        16871       2027      Bezirk
# 2474        54888       4774      Bezirk
# 2475       168903      21094      Bezirk
# 2476        40282       5808      Bezirk
# 2477        43170       5426      Bezirk
# 2478        18270       2413      Bezirk
# 2479        21083       2891      Bezirk
# 2480        36036       4530      Bezirk
# 2481         7852        978      Bezirk
# 2482        32944       3670      Bezirk
# 2483        47423       6363      Bezirk
# 2484        10161       1286      Bezirk
# 2485        32131       3003      Bezirk
# 2486        44784       4767      Bezirk
# 2487        29425       4314      Bezirk
# 2488        31784       3404      Bezirk
# 2489        18972       2220      Bezirk
# 2490        17865       2104      Bezirk
# 2491        30013       3066      Bezirk
# 2492        49895       5961      Bezirk
# 2493        32024       2824      Bezirk
# 2494        20660       2491      Bezirk
# 2495        17062       1704      Bezirk
# 2496        33661       3415      Bezirk
# 2497        23619       2419      Bezirk
# 2498      3583008     407408        Land
#
# [2499 rows x 6 columns]

# %% [markdown]
# ### Spalte "Einheitsnummer"

# %% [markdown]
# Hier kommt die Funktion `str.extract()` gelegen.

# %%
df['Einheit'].str.extract(r"^\.{6}(\d{4}) .+$")
# Out:
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26    0001
# 27    0002
# 28    0003
# 29    0004
# ...    ...
# 2469   NaN
# 2470   NaN
# 2471   NaN
# 2472   NaN
# 2473   NaN
# 2474   NaN
# 2475   NaN
# 2476   NaN
# 2477   NaN
# 2478   NaN
# 2479   NaN
# 2480   NaN
# 2481   NaN
# 2482   NaN
# 2483   NaN
# 2484   NaN
# 2485   NaN
# 2486   NaN
# 2487   NaN
# 2488   NaN
# 2489   NaN
# 2490   NaN
# 2491   NaN
# 2492   NaN
# 2493   NaN
# 2494   NaN
# 2495   NaN
# 2496   NaN
# 2497   NaN
# 2498   NaN
#
# [2499 rows x 1 columns]

# %% [markdown]
# Wir können den Output dieser Funktion für die neue Spalte setzen.

# %%
df['Einheitsnummer'] = df['Einheit'].str.extract(r"^\.{6}(\d{4}) .+$")

# %%
df.head(40)
# Out:
#                                Einheit  Geschieden   Ledig  Verheiratet  \
# 0                             - Aargau       50715  276123       296940
# 1             - Appenzell Ausserrhoden        4496   23055        24117
# 2              - Appenzell Innerrhoden         814    7338         6971
# 3                   - Basel-Landschaft       22994  113105       131580
# 4                        - Basel-Stadt       18693   89611        72481
# 5                       - Bern / Berne       84364  437186       439372
# 6                - Fribourg / Freiburg       23511  138940       131592
# 7                             - Genève       46072  224586       193557
# 8                             - Glarus        3066   16607        18015
# 9   - Graubünden / Grigioni / Grischun       14957   83298        87623
# 10                              - Jura        5786   31049        31408
# 11                            - Luzern       26541  181455       172144
# 12                         - Neuchâtel       17812   77637        72766
# 13                         - Nidwalden        3176   18392        18905
# 14                          - Obwalden        2311   16432        16562
# 15                      - Schaffhausen        6819   32404        35972
# 16                            - Schwyz       11639   66828        68701
# 17                         - Solothurn       22767  110681       118459
# 18                        - St. Gallen       39145  215628       219912
# 19                           - Thurgau       22240  113225       119530
# 20                            - Ticino       28986  146039       155489
# 21                               - Uri        1751   15323        16871
# 22                   - Valais / Wallis       26205  142216       149122
# 23                              - Vaud       65726  353300       319635
# 24                               - Zug        9147   53320        54888
# 25                            - Zürich      125889  666873       610396
# 26          ......0001 Aeugst am Albis         147     852          908
# 27       ......0002 Affoltern am Albis        1004    5000         5159
# 28               ......0003 Bonstetten         383    2336         2452
# 29          ......0004 Hausen am Albis         317    1433         1596
# 30                 ......0005 Hedingen         294    1559         1690
# 31          ......0006 Kappel am Albis          81     454          460
# 32                   ......0007 Knonau         161     897          970
# 33              ......0008 Maschwanden          44     292          279
# 34           ......0009 Mettmenstetten         355    2016         2168
# 35                 ......0010 Obfelden         332    2091         2401
# 36                ......0011 Ottenbach         242    1031         1209
# 37               ......0012 Rifferswil          77     461          486
# 38                ......0013 Stallikon         275    1410         1678
# 39        ......0014 Wettswil am Albis         364    1953         2409
#
#     Verwitwet Einheitstyp Einheitsnummer
# 0       29873      Kanton            NaN
# 1        2875      Kanton            NaN
# 2         851      Kanton            NaN
# 3       15539      Kanton            NaN
# 4       11023      Kanton            NaN
# 5       56513      Kanton            NaN
# 6       13403      Kanton            NaN
# 7       20496      Kanton            NaN
# 8        2338      Kanton            NaN
# 9       10724      Kanton            NaN
# 10       4538      Kanton            NaN
# 11      18613      Kanton            NaN
# 12       9890      Kanton            NaN
# 13       1946      Kanton            NaN
# 14       1771      Kanton            NaN
# 15       4638      Kanton            NaN
# 16       6920      Kanton            NaN
# 17      14499      Kanton            NaN
# 18      24365      Kanton            NaN
# 19      12428      Kanton            NaN
# 20      21428      Kanton            NaN
# 21       2027      Kanton            NaN
# 22      18131      Kanton            NaN
# 23      34632      Kanton            NaN
# 24       4774      Kanton            NaN
# 25      63173      Kanton            NaN
# 26         74    Gemeinde           0001
# 27        545    Gemeinde           0002
# 28        154    Gemeinde           0003
# 29        131    Gemeinde           0004
# 30        117    Gemeinde           0005
# 31         38    Gemeinde           0006
# 32         69    Gemeinde           0007
# 33         26    Gemeinde           0008
# 34        130    Gemeinde           0009
# 35        185    Gemeinde           0010
# 36         87    Gemeinde           0011
# 37         33    Gemeinde           0012
# 38         92    Gemeinde           0013
# 39        194    Gemeinde           0014

# %% [markdown]
# **Achtung: ** Dieser Trick funktioniert hier, weil die Kantone und Bezirke *keine* Nummer haben - wir schreiben dort jetzt einfach "NaN" hin. Würden wir dieselbe Regex-Extraktion auch auf Kantone anwenden, müssten wir aufpassen, dass wir die Werte der Gemeinden, die dann ebenfalls "NaN" wären, nicht wieder überschreiben würden.

# %% [markdown]
# ### Spalte "Einheitsname"

# %% [markdown]
# Es gibt zig Varianten, wie wir hier zum Ziel kommen können. Wir wählen mal den folgenden:
# - Spalte "Einheit" kopieren
# - Jeweils für Gemeinden, Bezirke, Kantone separat den ganzen Käse am Anfang rauslöschen, der nicht zum Namen gehört.

# %%
df['Einheitsname'] = df['Einheit']

# %%
df.head(2)
# Out:
#                     Einheit  Geschieden   Ledig  Verheiratet  Verwitwet  \
# 0                  - Aargau       50715  276123       296940      29873
# 1  - Appenzell Ausserrhoden        4496   23055        24117       2875
#
#   Einheitstyp Einheitsnummer              Einheitsname
# 0      Kanton            NaN                  - Aargau
# 1      Kanton            NaN  - Appenzell Ausserrhoden

# %%
# Gemeinden
df['Einheitsname'].str.replace(r"^\.{6}\d{4} ", "")
# Out:
# 0                                           - Aargau
# 1                           - Appenzell Ausserrhoden
# 2                            - Appenzell Innerrhoden
# 3                                 - Basel-Landschaft
# 4                                      - Basel-Stadt
# 5                                     - Bern / Berne
# 6                              - Fribourg / Freiburg
# 7                                           - Genève
# 8                                           - Glarus
# 9                 - Graubünden / Grigioni / Grischun
# 10                                            - Jura
# 11                                          - Luzern
# 12                                       - Neuchâtel
# 13                                       - Nidwalden
# 14                                        - Obwalden
# 15                                    - Schaffhausen
# 16                                          - Schwyz
# 17                                       - Solothurn
# 18                                      - St. Gallen
# 19                                         - Thurgau
# 20                                          - Ticino
# 21                                             - Uri
# 22                                 - Valais / Wallis
# 23                                            - Vaud
# 24                                             - Zug
# 25                                          - Zürich
# 26                                   Aeugst am Albis
# 27                                Affoltern am Albis
# 28                                        Bonstetten
# 29                                   Hausen am Albis
#                             ...
# 2469                           >> Kanton Basel-Stadt
# 2470                                >> Kanton Glarus
# 2471                             >> Kanton Nidwalden
# 2472                              >> Kanton Obwalden
# 2473                                   >> Kanton Uri
# 2474                                   >> Kanton Zug
# 2475             >> Verwaltungskreis Bern-Mittelland
# 2476                 >> Verwaltungskreis Biel/Bienne
# 2477                    >> Verwaltungskreis Emmental
# 2478    >> Verwaltungskreis Frutigen-Niedersimmental
# 2479        >> Verwaltungskreis Interlaken-Oberhasli
# 2480                  >> Verwaltungskreis Oberaargau
# 2481        >> Verwaltungskreis Obersimmental-Saanen
# 2482                     >> Verwaltungskreis Seeland
# 2483                        >> Verwaltungskreis Thun
# 2484                          >> Wahlkreis Entlebuch
# 2485                           >> Wahlkreis Hochdorf
# 2486                        >> Wahlkreis Luzern-Land
# 2487                       >> Wahlkreis Luzern-Stadt
# 2488                           >> Wahlkreis Rheintal
# 2489                          >> Wahlkreis Rorschach
# 2490                      >> Wahlkreis Sarganserland
# 2491                         >> Wahlkreis See-Gaster
# 2492                         >> Wahlkreis St. Gallen
# 2493                             >> Wahlkreis Sursee
# 2494                         >> Wahlkreis Toggenburg
# 2495                         >> Wahlkreis Werdenberg
# 2496                                >> Wahlkreis Wil
# 2497                           >> Wahlkreis Willisau
# 2498                                         Schweiz
# Name: Einheitsname, Length: 2499, dtype: object

# %%
# Gemeinden
df['Einheitsname'] = df['Einheitsname'].str.replace(r"^\.{6}\d{4} ", "")

# %%
# Bezirke
df['Einheitsname'] = df['Einheitsname'].str.replace(r"^>> ", "")

# %%
# Kantone
df['Einheitsname'] = df['Einheitsname'].str.replace(r"^- ", "")

# %%
df
# Out:
#                                            Einheit  Geschieden    Ledig  \
# 0                                         - Aargau       50715   276123
# 1                         - Appenzell Ausserrhoden        4496    23055
# 2                          - Appenzell Innerrhoden         814     7338
# 3                               - Basel-Landschaft       22994   113105
# 4                                    - Basel-Stadt       18693    89611
# 5                                   - Bern / Berne       84364   437186
# 6                            - Fribourg / Freiburg       23511   138940
# 7                                         - Genève       46072   224586
# 8                                         - Glarus        3066    16607
# 9               - Graubünden / Grigioni / Grischun       14957    83298
# 10                                          - Jura        5786    31049
# 11                                        - Luzern       26541   181455
# 12                                     - Neuchâtel       17812    77637
# 13                                     - Nidwalden        3176    18392
# 14                                      - Obwalden        2311    16432
# 15                                  - Schaffhausen        6819    32404
# 16                                        - Schwyz       11639    66828
# 17                                     - Solothurn       22767   110681
# 18                                    - St. Gallen       39145   215628
# 19                                       - Thurgau       22240   113225
# 20                                        - Ticino       28986   146039
# 21                                           - Uri        1751    15323
# 22                               - Valais / Wallis       26205   142216
# 23                                          - Vaud       65726   353300
# 24                                           - Zug        9147    53320
# 25                                        - Zürich      125889   666873
# 26                      ......0001 Aeugst am Albis         147      852
# 27                   ......0002 Affoltern am Albis        1004     5000
# 28                           ......0003 Bonstetten         383     2336
# 29                      ......0004 Hausen am Albis         317     1433
# ...                                            ...         ...      ...
# 2469                         >> Kanton Basel-Stadt       18693    89611
# 2470                              >> Kanton Glarus        3066    16607
# 2471                           >> Kanton Nidwalden        3176    18392
# 2472                            >> Kanton Obwalden        2311    16432
# 2473                                 >> Kanton Uri        1751    15323
# 2474                                 >> Kanton Zug        9147    53320
# 2475           >> Verwaltungskreis Bern-Mittelland       33777   182532
# 2476               >> Verwaltungskreis Biel/Bienne       10231    42596
# 2477                  >> Verwaltungskreis Emmental        6777    40831
# 2478  >> Verwaltungskreis Frutigen-Niedersimmental        2889    16112
# 2479      >> Verwaltungskreis Interlaken-Oberhasli        3944    19446
# 2480                >> Verwaltungskreis Oberaargau        6296    33065
# 2481      >> Verwaltungskreis Obersimmental-Saanen        1010     6845
# 2482                   >> Verwaltungskreis Seeland        5750    29711
# 2483                      >> Verwaltungskreis Thun        9126    43818
# 2484                        >> Wahlkreis Entlebuch         895    10905
# 2485                         >> Wahlkreis Hochdorf        4725    31103
# 2486                      >> Wahlkreis Luzern-Land        7313    42142
# 2487                     >> Wahlkreis Luzern-Stadt        7006    40545
# 2488                         >> Wahlkreis Rheintal        5535    30340
# 2489                        >> Wahlkreis Rorschach        3837    17237
# 2490                    >> Wahlkreis Sarganserland        2898    16975
# 2491                       >> Wahlkreis See-Gaster        4970    27714
# 2492                       >> Wahlkreis St. Gallen       10213    55644
# 2493                           >> Wahlkreis Sursee        3863    32943
# 2494                       >> Wahlkreis Toggenburg        3198    19559
# 2495                       >> Wahlkreis Werdenberg        3035    16152
# 2496                              >> Wahlkreis Wil        5459    32007
# 2497                         >> Wahlkreis Willisau        2739    23817
# 2498                                       Schweiz      685622  3650651
#
#       Verheiratet  Verwitwet Einheitstyp Einheitsnummer  \
# 0          296940      29873      Kanton            NaN
# 1           24117       2875      Kanton            NaN
# 2            6971        851      Kanton            NaN
# 3          131580      15539      Kanton            NaN
# 4           72481      11023      Kanton            NaN
# 5          439372      56513      Kanton            NaN
# 6          131592      13403      Kanton            NaN
# 7          193557      20496      Kanton            NaN
# 8           18015       2338      Kanton            NaN
# 9           87623      10724      Kanton            NaN
# 10          31408       4538      Kanton            NaN
# 11         172144      18613      Kanton            NaN
# 12          72766       9890      Kanton            NaN
# 13          18905       1946      Kanton            NaN
# 14          16562       1771      Kanton            NaN
# 15          35972       4638      Kanton            NaN
# 16          68701       6920      Kanton            NaN
# 17         118459      14499      Kanton            NaN
# 18         219912      24365      Kanton            NaN
# 19         119530      12428      Kanton            NaN
# 20         155489      21428      Kanton            NaN
# 21          16871       2027      Kanton            NaN
# 22         149122      18131      Kanton            NaN
# 23         319635      34632      Kanton            NaN
# 24          54888       4774      Kanton            NaN
# 25         610396      63173      Kanton            NaN
# 26            908         74    Gemeinde           0001
# 27           5159        545    Gemeinde           0002
# 28           2452        154    Gemeinde           0003
# 29           1596        131    Gemeinde           0004
# ...           ...        ...         ...            ...
# 2469        72481      11023      Bezirk            NaN
# 2470        18015       2338      Bezirk            NaN
# 2471        18905       1946      Bezirk            NaN
# 2472        16562       1771      Bezirk            NaN
# 2473        16871       2027      Bezirk            NaN
# 2474        54888       4774      Bezirk            NaN
# 2475       168903      21094      Bezirk            NaN
# 2476        40282       5808      Bezirk            NaN
# 2477        43170       5426      Bezirk            NaN
# 2478        18270       2413      Bezirk            NaN
# 2479        21083       2891      Bezirk            NaN
# 2480        36036       4530      Bezirk            NaN
# 2481         7852        978      Bezirk            NaN
# 2482        32944       3670      Bezirk            NaN
# 2483        47423       6363      Bezirk            NaN
# 2484        10161       1286      Bezirk            NaN
# 2485        32131       3003      Bezirk            NaN
# 2486        44784       4767      Bezirk            NaN
# 2487        29425       4314      Bezirk            NaN
# 2488        31784       3404      Bezirk            NaN
# 2489        18972       2220      Bezirk            NaN
# 2490        17865       2104      Bezirk            NaN
# 2491        30013       3066      Bezirk            NaN
# 2492        49895       5961      Bezirk            NaN
# 2493        32024       2824      Bezirk            NaN
# 2494        20660       2491      Bezirk            NaN
# 2495        17062       1704      Bezirk            NaN
# 2496        33661       3415      Bezirk            NaN
# 2497        23619       2419      Bezirk            NaN
# 2498      3583008     407408        Land            NaN
#
#                                    Einheitsname
# 0                                        Aargau
# 1                        Appenzell Ausserrhoden
# 2                         Appenzell Innerrhoden
# 3                              Basel-Landschaft
# 4                                   Basel-Stadt
# 5                                  Bern / Berne
# 6                           Fribourg / Freiburg
# 7                                        Genève
# 8                                        Glarus
# 9              Graubünden / Grigioni / Grischun
# 10                                         Jura
# 11                                       Luzern
# 12                                    Neuchâtel
# 13                                    Nidwalden
# 14                                     Obwalden
# 15                                 Schaffhausen
# 16                                       Schwyz
# 17                                    Solothurn
# 18                                   St. Gallen
# 19                                      Thurgau
# 20                                       Ticino
# 21                                          Uri
# 22                              Valais / Wallis
# 23                                         Vaud
# 24                                          Zug
# 25                                       Zürich
# 26                              Aeugst am Albis
# 27                           Affoltern am Albis
# 28                                   Bonstetten
# 29                              Hausen am Albis
# ...                                         ...
# 2469                         Kanton Basel-Stadt
# 2470                              Kanton Glarus
# 2471                           Kanton Nidwalden
# 2472                            Kanton Obwalden
# 2473                                 Kanton Uri
# 2474                                 Kanton Zug
# 2475           Verwaltungskreis Bern-Mittelland
# 2476               Verwaltungskreis Biel/Bienne
# 2477                  Verwaltungskreis Emmental
# 2478  Verwaltungskreis Frutigen-Niedersimmental
# 2479      Verwaltungskreis Interlaken-Oberhasli
# 2480                Verwaltungskreis Oberaargau
# 2481      Verwaltungskreis Obersimmental-Saanen
# 2482                   Verwaltungskreis Seeland
# 2483                      Verwaltungskreis Thun
# 2484                        Wahlkreis Entlebuch
# 2485                         Wahlkreis Hochdorf
# 2486                      Wahlkreis Luzern-Land
# 2487                     Wahlkreis Luzern-Stadt
# 2488                         Wahlkreis Rheintal
# 2489                        Wahlkreis Rorschach
# 2490                    Wahlkreis Sarganserland
# 2491                       Wahlkreis See-Gaster
# 2492                       Wahlkreis St. Gallen
# 2493                           Wahlkreis Sursee
# 2494                       Wahlkreis Toggenburg
# 2495                       Wahlkreis Werdenberg
# 2496                              Wahlkreis Wil
# 2497                         Wahlkreis Willisau
# 2498                                    Schweiz
#
# [2499 rows x 8 columns]
