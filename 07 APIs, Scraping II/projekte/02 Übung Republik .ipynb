# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
republikwebsite = requests.get('https://www.republik.ch/feed')

# %%
republikwebsite.text
# Out:
# '<!DOCTYPE html><html lang="de"><head><meta charSet="utf-8" class="next-head"/><link rel="preload" href="https://cdn.republik.space/frontend/_next/a39b88de-1385-4457-9a5a-c0d9addd37d2/page/feed.js" as="script"/><link rel="preload" href="https://cdn.republik.space/frontend/_next/a39b88de-1385-4457-9a5a-c0d9addd37d2/page/_error.js" as="script"/><link rel="preload" href="https://cdn.republik.space/frontend/_next/1229b7c2184cb4462f7312df0c130231/app.js" as="script"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><style>@font-face{font-family:"Rubis-Regular";src:url(https://cdn.republik.space/s3/republik-assets/fonts/rubis-regular.eot);src:url(https://cdn.republik.space/s3/republik-assets/fonts/rubis-regular.eot?#iefix) format("embedded-opentype"),url(https://cdn.republik.space/s3/republik-assets/fonts/rubis-regular.woff2) format("woff2"),url(https://cdn.republik.space/s3/republik-assets/fonts/rubis-regular.woff) 
# ...
