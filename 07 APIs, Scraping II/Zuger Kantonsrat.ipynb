# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page=1")
soup = BeautifulSoup(r.text, 'html.parser')

# %%
def minidict(listenelement):
    
    for element in listenelement:
    
        td_list = element.find_all('td')
        href = td_list[0].find('a')['href']
        geschäft = td_list[1].text
        stand = td_list[2].text
        zuständig = td_list[3].text
        geschäftsart = td_list[4].text
        status = td_list[5].text

        mini_dict = {"url":href,
          "geschäft": geschäft,
          "stand": stand,
          "zuständig": zuständig,
          "geschäftsart":geschäftsart,
          "status": status}
        
        return mini_dict

# %%
minidict(trlist)
# Out:
# {'url': '/gast/geschaefte/1317',
#  'geschäft': 'Genehmigung der Schlussabrechnung betreffend Restaurierung und Umbau der Athene sowie Erstellung eines Ergänzungsneubaus',
#  'stand': 'Datenmigration',
#  'zuständig': '',
#  'geschäftsart': 'Verschiedenes',
#  'status': 'abgeschlossen'}

# %%
trlist
# Out:
# [<tr>
#  <td><a href="/gast/geschaefte/1317">487</a></td>
#  <td><a href="/gast/geschaefte/1317">Genehmigung der Schlussabrechnung betreffend Restaurierung und Umbau der Athene sowie Erstellung eines Ergänzungsneubaus</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1316">482</a></td>
#  <td><a href="/gast/geschaefte/1316">Genehmigung von acht Schlussabrechnungen:</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1315">469</a></td>
#  <td><a href="/gast/geschaefte/1315">Genehmigung der Schlussabrechnung (K42) betreffend den Umbau der Kantonsstrasse 4c, Gemeinde Cham, Abschnitt Bärenplatz - Bahnhofstrasse, inklusive Kreisel Rabenplatz</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1314">449</a></td>
#  <td><a href="/gast/geschaefte/1314">Strassenbauprogramm 1998 - 2003, Schlussbericht und Schlussabrechnung</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1313">448</a></td>
#  <td><a href="/gast/geschaefte/1313">Genehmigung der Schlussabrechnung betreffend Beitrag an den Pflegeheimteil des Betagtenzentrums Neustadt Zug</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1312">445</a></td>
#  <td><a href="/gast/geschaefte/1312">Genehmigung der Schlussabrechnung für die Umfahrungen Zug/Baar (UZB), Gemeinden Zug und Baar</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1311">427</a></td>
#  <td><a href="/gast/geschaefte/1311">Genehmigung von acht Schlussabrechnungen:</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1310">417</a></td>
#  <td><a href="/gast/geschaefte/1310">Genehmigung der Schlussabrechnung für das Vorprojekt Stadtbahn Zug</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1309">304</a></td>
#  <td><a href="/gast/geschaefte/1309">Motion von Manuela Weichelt betreffend HIV-Prävention in Untersuchungshaft und im Strafvollzug</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1712">282</a></td>
#  <td><a href="/gast/geschaefte/1712">Motion von Christoph Hohler betreffend Radstrecken ins Ägerital</a></td>
#  <td class="hidden-xs">Frist erstreckt</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1308">231</a></td>
#  <td><a href="/gast/geschaefte/1308">Genehmigung der Schlussabrechnung (K98) betreffend den Ausbau der Kantonsstrasse 25a, Teilstrecke Zollweid - Matten, Gemeinde Hünenberg</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1307">207</a></td>
#  <td><a href="/gast/geschaefte/1307">Genehmigung der Schlussabrechnung (K40) betreffend die Kernentlastung II. Etappe, Gemeinde Baar</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1334">81</a></td>
#  <td><a href="/gast/geschaefte/1334">Motion der vorberatenden Kommission betreffend "Zuger Initiative für vermehrte Mitsprache im Strassenverkehr"</a></td>
#  <td class="hidden-xs">Datenmigration</td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>]

# %%
#Das ist meine Liste mit allen tr tags
trlist = soup.find_all("tr")[2:]

# %%
len(trlist)
# Out:
# 50

# %%
temp = trlist[0].find_all('td')
for td_tag in temp:
    print(td_tag.text)
# Out:
# 3010
# Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug
# Einreichung
# Baudirektion
# Postulat
# hängig

# %%
temp[0].find('a')['href']
# Out:
# '/gast/geschaefte/1998'

# %%
len(trlist)
# Out:
# 50

# %%
td_list = trlist[0].find_all('td')

# %%
td_list[0].find('a')['href']
# Out:
# '/gast/geschaefte/1998'

# %%
td_list
# Out:
# [<td><a href="/gast/geschaefte/1998">3010</a></td>,
#  <td><a href="/gast/geschaefte/1998">Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug</a></td>,
#  <td class="hidden-xs">Einreichung</td>,
#  <td class="hidden-xs">Baudirektion</td>,
#  <td class="hidden-xs">Postulat</td>,
#  <td class="hidden-xs">hängig</td>]

# %%
td_list = trlist[0].find_all('td')
url = td_list[0].find('a')['href']
geschäft = td_list[1].text
stand = td_list[2].text
zuständig = td_list[3].text
geschäftsart = td_list[4].text
status = td_list[5].text

mini_dict = {"url":url,
          "geschäft": geschäft,
          "stand": stand,
          "zuständig": zuständig,
          "geschäftsart":geschäftsart,
          "status": status}

# %%
mini_dict
# Out:
# {'url': '/gast/geschaefte/1998',
#  'geschäft': 'Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug',
#  'stand': 'Einreichung',
#  'zuständig': 'Baudirektion',
#  'geschäftsart': 'Postulat',
#  'status': 'hängig'}

# %%
seite_eins = []
for element in trlist:
    
    td_list = element.find_all('td')
    url = td_list[0].find('a')['href']
    geschäft = td_list[1].text
    stand = td_list[2].text
    zuständig = td_list[3].text
    geschäftsart = td_list[4].text
    status = td_list[5].text

    mini_dict = {"url":url,
          "geschäft": geschäft,
          "stand": stand,
          "zuständig": zuständig,
          "geschäftsart":geschäftsart,
          "status": status}
    
    seite_eins.append(mini_dict)

# %%
import pandas as pd
pd.DataFrame(seite_eins)
# Out:
#                                              geschäft  \
# 0   Postulat von Ivo Egger, Stéphanie Vuichard, Ha...
# 1   Postulat von Stéphanie Vuichard, Mariann Hess ...
# 2   Motion von Rainer Leemann und Michael Arnold b...
# 3   Interpellation der SP-Fraktion betreffend Pest...
# 4   Interpellation von Pirmin Andermatt und Heini ...
# 5   Kantonsrats-Ersatzwahl in der Einwohnergemeind...
# 6   Motion der CVP-Fraktion betreffend bedarfsgere...
# 7   Postulat von Manuela Leemann, Benny Elsener un...
# 8   Interpellation von Hans Baumgartner, Manuela K...
# 9   Kantonsrats-Ersatzwahl in der Einwohnergemeind...
# 10  Interpellation von Pirmin Andermatt, Zari Dzaf...
# 11  Motion der FDP-Fraktion betreffend mehr Kompet...
# 12  Kantonsratsbeschluss betreffend Kenntnisnahme ...
# 13  Kleine Anfrage von Andreas Lustenberger betref...
# 14  Kantonsratsbeschluss betreffend Beitritt zum G...
# 15  Interpellation der CVP-Fraktion betreffend Aus...
# 16  Interpellation der FDP-Fraktion betreffend kan...
# 17  Motion von Anna Bieri und Barbara Häseli betre...
# 18  Postulat der SP-Fraktion und der Fraktion Alte...
# 19  Kantonsratsbeschluss betreffend Anpassung des ...
# 20  Postulat von Fabio Iten und Patrick Iten betre...
# 21  Interpellation von Ivo Egger und Zari Dzaferi ...
# 22  Petition «Forderungen der Pflegefachfrauen der...
# 23                  Petition «Frauen*streik Manifest»
# 24  Geschäftsbericht 2018 der Kindes- und Erwachse...
# 25                   Änderung des Datenschutzgesetzes
# 26  Kleine Anfrage von Rita Hofer betreffend Umset...
# 27  Kleine Anfrage der SP-Fraktion betreffend Kamp...
# 28  Interpellation von Daniel Stadlin betreffend N...
# 29  Änderung des Einführungsgesetzes zu den Bundes...
# 30  Interpellation von Stéphanie Vuichard, Mariann...
# 31  Interpellation von Anna Bieri und Manuela Leem...
# 32  Interpellation von Ivo Egger, Andreas Hürliman...
# 33  Postulat der SVP-Fraktion betreffend Förderung...
# 34  Interpellation der SP-Fraktion betreffend Revi...
# 35  Interpellation der SP-Fraktion betreffend Eins...
# 36  Postulat der SP-Fraktion betreffend wirksames ...
# 37  Interpellation von Ivo Egger, Esther Haas, Han...
# 38  Postulat von Tabea Zimmermann Gibson, Andreas ...
# 39  Ersatzwahl eines neuen Mitglieds der Schätzung...
# 40  Kantonsratsbeschluss betreffend Kenntnisnahme ...
# 41  Rechenschaftsberichte 2017/2018 des Verwaltung...
# 42  Zwischenbericht zu den per Ende März 2019 zur ...
# 43  Interpellation von Manuela Leemann und Isabel ...
# 44  Postulat der CVP-Fraktion betreffend klimaneut...
# 45  Feststellung der Gültigkeit der stillen Wahl e...
# 46  Kantonsratsbeschluss betreffend Objektkredit f...
# 47                  ZFA-Reform 2018: Abschlussbericht
# 48  Interpellation der CVP-Fraktion betreffend bes...
# 49                              Geschäftsbericht 2018
#
#                                      geschäftsart  \
# 0                                        Postulat
# 1                                        Postulat
# 2                                          Motion
# 3                                  Interpellation
# 4                                  Interpellation
# 5                                          Wahlen
# 6                                          Motion
# 7                                        Postulat
# 8                                  Interpellation
# 9                                          Wahlen
# 10                                 Interpellation
# 11                                         Motion
# 12  Kantonsratsbeschluss (nicht referendumsfähig)
# 13                                 Kleine Anfrage
# 14                                      Konkordat
# 15                                 Interpellation
# 16                                 Interpellation
# 17                                         Motion
# 18                                       Postulat
# 19  Kantonsratsbeschluss (nicht referendumsfähig)
# 20                                       Postulat
# 21                                 Interpellation
# 22                                       Petition
# 23                                       Petition
# 24                                  Verschiedenes
# 25                                         Gesetz
# 26                                 Kleine Anfrage
# 27                                 Kleine Anfrage
# 28                                 Interpellation
# 29                                         Gesetz
# 30                                 Interpellation
# 31                                 Interpellation
# 32                                 Interpellation
# 33                                       Postulat
# 34                                 Interpellation
# 35                                 Interpellation
# 36                                       Postulat
# 37                                 Interpellation
# 38                                       Postulat
# 39                                         Wahlen
# 40                                  Verschiedenes
# 41                                  Verschiedenes
# 42                                  Verschiedenes
# 43                                 Interpellation
# 44                                       Postulat
# 45                                         Wahlen
# 46        Kantonsratsbeschluss (referendumsfähig)
# 47                                  Verschiedenes
# 48                                 Interpellation
# 49                                  Verschiedenes
#
#                             stand         status                    url  \
# 0                     Einreichung         hängig  /gast/geschaefte/1998
# 1                     Einreichung         hängig  /gast/geschaefte/1997
# 2                     Einreichung         hängig  /gast/geschaefte/1996
# 3                     Einreichung         hängig  /gast/geschaefte/1995
# 4                     Einreichung         hängig  /gast/geschaefte/1994
# 5                    Traktandiert         hängig  /gast/geschaefte/1993
# 6                     Einreichung         hängig  /gast/geschaefte/1992
# 7    Überweisung an Regierungsrat         hängig  /gast/geschaefte/1991
# 8    Überweisung an Regierungsrat         hängig  /gast/geschaefte/1990
# 9   Wahl: Feststellung Gültigkeit  abgeschlossen  /gast/geschaefte/1989
# 10   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1988
# 11   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1987
# 12            Kommission bestellt         hängig  /gast/geschaefte/1986
# 13     Antwort des Regierungsrats  abgeschlossen  /gast/geschaefte/1985
# 14            Kommission bestellt         hängig  /gast/geschaefte/1984
# 15   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1983
# 16   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1982
# 17             Erheblicherklärung         hängig  /gast/geschaefte/1981
# 18               Nichtüberweisung  abgeschlossen  /gast/geschaefte/1979
# 19            Kommission bestellt         hängig  /gast/geschaefte/1980
# 20   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1978
# 21   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1977
# 22      Überweisung an Kommission         hängig  /gast/geschaefte/1976
# 23      Überweisung an Kommission         hängig  /gast/geschaefte/1975
# 24                                 abgeschlossen  /gast/geschaefte/1974
# 25            Kommission bestellt         hängig  /gast/geschaefte/1973
# 26     Antwort des Regierungsrats  abgeschlossen  /gast/geschaefte/1972
# 27     Antwort des Regierungsrats  abgeschlossen  /gast/geschaefte/1971
# 28   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1970
# 29            Kommission bestellt         hängig  /gast/geschaefte/1969
# 30   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1968
# 31   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1967
# 32   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1966
# 33   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1965
# 34   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1964
# 35   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1963
# 36                   Traktandiert         hängig  /gast/geschaefte/1962
# 37   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1961
# 38                   Traktandiert         hängig  /gast/geschaefte/1960
# 39                           Wahl  abgeschlossen  /gast/geschaefte/1959
# 40                                 abgeschlossen  /gast/geschaefte/1958
# 41                                 abgeschlossen  /gast/geschaefte/1957
# 42                                 abgeschlossen  /gast/geschaefte/1956
# 43                   Traktandiert         hängig  /gast/geschaefte/1954
# 44   Überweisung an Regierungsrat         hängig  /gast/geschaefte/1953
# 45  Wahl: Feststellung Gültigkeit  abgeschlossen  /gast/geschaefte/1955
# 46            Kommission bestellt         hängig  /gast/geschaefte/1951
# 47                   Traktandiert         hängig  /gast/geschaefte/1952
# 48                   Traktandiert         hängig  /gast/geschaefte/1950
# 49                                 abgeschlossen  /gast/geschaefte/1949
#
#                            zuständig
# 0                       Baudirektion
# 1                       Baudirektion
# 2               Gesundheitsdirektion
# 3                       Baudirektion
# 4                    Finanzdirektion
# 5                      Staatskanzlei
# 6   Direktion für Bildung und Kultur
# 7                       Baudirektion
# 8                       Baudirektion
# 9                      Staatskanzlei
# 10                      Baudirektion
# 11  Direktion für Bildung und Kultur
# 12         Volkswirtschaftsdirektion
# 13              Direktion des Innern
# 14              Sicherheitsdirektion
# 15                      Baudirektion
# 16                   Finanzdirektion
# 17              Gesundheitsdirektion
# 18                   Finanzdirektion
# 19                      Baudirektion
# 20                      Baudirektion
# 21                      Baudirektion
# 22          Justizprüfungskommission
# 23          Justizprüfungskommission
# 24          Justizprüfungskommission
# 25              Sicherheitsdirektion
# 26  Direktion für Bildung und Kultur
# 27                   Finanzdirektion
# 28                      Baudirektion
# 29         Volkswirtschaftsdirektion
# 30                      Baudirektion
# 31  Direktion für Bildung und Kultur
# 32                      Baudirektion
# 33  Direktion für Bildung und Kultur
# 34                      Baudirektion
# 35              Direktion des Innern
# 36              Sicherheitsdirektion
# 37                      Baudirektion
# 38                   Finanzdirektion
# 39          Justizprüfungskommission
# 40              Sicherheitsdirektion
# 41                Verwaltungsgericht
# 42                     Staatskanzlei
# 43                      Baudirektion
# 44                      Baudirektion
# 45                     Staatskanzlei
# 46                      Baudirektion
# 47                   Finanzdirektion
# 48                      Baudirektion
# 49                   Finanzdirektion

# %%
lst = [1,2,3,4,5,6]

# %%
trlist[0].find_all('td')[0]
# Out:
# <td><a href="/gast/geschaefte/1998">3010</a></td>

# %%
trlist[0].find_all('td')[0]
# Out:
# <td><a href="/gast/geschaefte/1998">3010</a></td>

# %%
newlst = []
for geschäfte in trlist:

# %%
trlist
# Out:
# [<tr>
#  <td><a href="/gast/geschaefte/1998">3010</a></td>
#  <td><a href="/gast/geschaefte/1998">Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug</a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1997">3009</a></td>
#  <td><a href="/gast/geschaefte/1997">Postulat von Stéphanie Vuichard, Mariann Hess und Rita Hofer betreffend Biodiversitätsförderung</a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1996">3008</a></td>
#  <td><a href="/gast/geschaefte/1996">Motion von Rainer Leemann und Michael Arnold betreffend Standesinitiative: Gleiches Recht für jede Mutter und nicht nur für Politikerinnen
#  </a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Gesundheitsdirektion</td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1995">3007</a></td>
#  <td><a href="/gast/geschaefte/1995">Interpellation der SP-Fraktion betreffend Pestizide und Nitrat im Zuger Trinkwasser</a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1994">3006</a></td>
#  <td><a href="/gast/geschaefte/1994">Interpellation von Pirmin Andermatt und Heini Schmid betreffend Nutzung des historisch tiefen Zinsumfeldes und der guten Bonität des Kantons Zug zu Gunsten der Zuger Bevölkerung
#  </a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1993">3005</a></td>
#  <td><a href="/gast/geschaefte/1993">Kantonsrats-Ersatzwahl in der Einwohnergemeinde Zug</a></td>
#  <td class="hidden-xs">Traktandiert</td>
#  <td class="hidden-xs">Staatskanzlei</td>
#  <td class="hidden-xs">Wahlen</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1992">3004</a></td>
#  <td><a href="/gast/geschaefte/1992">Motion der CVP-Fraktion betreffend bedarfsgerechte Einführung von Tagesschulen
#  </a></td>
#  <td class="hidden-xs">Einreichung</td>
#  <td class="hidden-xs">Direktion für Bildung und Kultur</td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1991">3003</a></td>
#  <td><a href="/gast/geschaefte/1991">Postulat von Manuela Leemann, Benny Elsener und Richard Rüegg betreffend stufenlose Unterführung Brüggli
#  </a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1990">3002</a></td>
#  <td><a href="/gast/geschaefte/1990">Interpellation von Hans Baumgartner, Manuela Käch, Jean Luc Mösch, Brigitte Wenzin Widmer, Rainer Suter, Thomas Gander, Drin Alaj, Petra Muheim Quick und Claus Soltermann betreffend Vorhaben Richtplanfestsetzung Kiesabbau Hatwil-Hubletzen, Gemeinde Cham
#  </a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1989">3001</a></td>
#  <td><a href="/gast/geschaefte/1989">Kantonsrats-Ersatzwahl in der Einwohnergemeinde Hünenberg</a></td>
#  <td class="hidden-xs">Wahl: Feststellung Gültigkeit</td>
#  <td class="hidden-xs">Staatskanzlei</td>
#  <td class="hidden-xs">Wahlen</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1988">3000</a></td>
#  <td><a href="/gast/geschaefte/1988">Interpellation von Pirmin Andermatt, Zari Dzaferi und Urs Andermatt betreffend 5G
#  </a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1987">2999</a></td>
#  <td><a href="/gast/geschaefte/1987">Motion der FDP-Fraktion betreffend mehr Kompetenz und Flexibilität an die Gemeinden im Führen der Oberstufe nach deren Bedürfnissen</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Direktion für Bildung und Kultur</td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1986">2998</a></td>
#  <td><a href="/gast/geschaefte/1986">Kantonsratsbeschluss betreffend Kenntnisnahme vom mehrjährigen Leistungsauftrag 2020–2023 für die Fachhochschule Zentralschweiz (Hochschule Luzern)</a></td>
#  <td class="hidden-xs">Kommission bestellt</td>
#  <td class="hidden-xs">Volkswirtschaftsdirektion</td>
#  <td class="hidden-xs">Kantonsratsbeschluss (nicht referendumsfähig)</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1985">2997</a></td>
#  <td><a href="/gast/geschaefte/1985">Kleine Anfrage von Andreas Lustenberger betreffend Unterkünfte für asylsuchende Menschen</a></td>
#  <td class="hidden-xs">Antwort des Regierungsrats</td>
#  <td class="hidden-xs">Direktion des Innern</td>
#  <td class="hidden-xs">Kleine Anfrage</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1984">2996</a></td>
#  <td><a href="/gast/geschaefte/1984">Kantonsratsbeschluss betreffend Beitritt zum Gesamtschweizerischen Geldspielkonkordat (GSK) und Beitritt zur Interkantonalen Vereinbarung betreffend die gemeinsame Durchführung von Geldspielen (IKV 2020)</a></td>
#  <td class="hidden-xs">Kommission bestellt</td>
#  <td class="hidden-xs">Sicherheitsdirektion</td>
#  <td class="hidden-xs">Konkordat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1983">2995</a></td>
#  <td><a href="/gast/geschaefte/1983">Interpellation der CVP-Fraktion betreffend Aushub - Deponien im Kanton Zug</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1982">2994</a></td>
#  <td><a href="/gast/geschaefte/1982">Interpellation der FDP-Fraktion betreffend kantonaler Arbeitsplatz im 21. Jahrhundert</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1981">2993</a></td>
#  <td><a href="/gast/geschaefte/1981">Motion von Anna Bieri und Barbara Häseli betreffend Standesinitiative betreffend politisches Mandat auch bei Mutterschaft</a></td>
#  <td class="hidden-xs">Erheblicherklärung</td>
#  <td class="hidden-xs">Gesundheitsdirektion</td>
#  <td class="hidden-xs">Motion</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1979">2992</a></td>
#  <td><a href="/gast/geschaefte/1979">Postulat der SP-Fraktion und der Fraktion Alternative - die Grünen betreffend 150 Millionen Franken Überschuss, unnötige Sparmassnahmen rückgängig machen</a></td>
#  <td class="hidden-xs">Nichtüberweisung</td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1980">2991</a></td>
#  <td><a href="/gast/geschaefte/1980">Kantonsratsbeschluss betreffend Anpassung des kantonalen Richtplans (L 11 Gebiete für Erholung und Sport; V 2 Nationalstrassen; V 3 Kantonsstrassen; V 6 Busverkehr/Feinverteiler, u. a. auf Eigentrassee; V 9 Radverkehr; V 10 Kantonales Wanderwegnetz; V 12 Prioritäten bei den Verkehrsvorhaben; E 15 Energie) </a></td>
#  <td class="hidden-xs">Kommission bestellt</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Kantonsratsbeschluss (nicht referendumsfähig)</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1978">2990</a></td>
#  <td><a href="/gast/geschaefte/1978">Postulat von Fabio Iten und Patrick Iten betreffend Massnahmen für einen optimalen Verkehrsfluss während der Sanierung der Lorzental-Kantonsstrasse
#  </a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1977">2989</a></td>
#  <td><a href="/gast/geschaefte/1977">Interpellation von Ivo Egger und Zari Dzaferi betreffend Förderung des Veloverkehrs für Arbeits- und Schulweg</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1976">2988</a></td>
#  <td><a href="/gast/geschaefte/1976">Petition «Forderungen der Pflegefachfrauen der Spitalexternen Pflege des Kantons Zug»</a></td>
#  <td class="hidden-xs">Überweisung an Kommission</td>
#  <td class="hidden-xs">Justizprüfungskommission</td>
#  <td class="hidden-xs">Petition</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1975">2987</a></td>
#  <td><a href="/gast/geschaefte/1975">Petition «Frauen*streik Manifest»</a></td>
#  <td class="hidden-xs">Überweisung an Kommission</td>
#  <td class="hidden-xs">Justizprüfungskommission</td>
#  <td class="hidden-xs">Petition</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1974">2986</a></td>
#  <td><a href="/gast/geschaefte/1974">Geschäftsbericht 2018 der Kindes- und Erwachsenenschutzbehörde (KESB)
#  </a></td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Justizprüfungskommission</td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1973">2985</a></td>
#  <td><a href="/gast/geschaefte/1973">Änderung des Datenschutzgesetzes</a></td>
#  <td class="hidden-xs">Kommission bestellt</td>
#  <td class="hidden-xs">Sicherheitsdirektion</td>
#  <td class="hidden-xs">Gesetz</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1972">2984</a></td>
#  <td><a href="/gast/geschaefte/1972">Kleine Anfrage von Rita Hofer betreffend Umsetzung Lehrplan 21 an den Kantonsschulen Zug und Menzingen </a></td>
#  <td class="hidden-xs">Antwort des Regierungsrats</td>
#  <td class="hidden-xs">Direktion für Bildung und Kultur</td>
#  <td class="hidden-xs">Kleine Anfrage</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1971">2983</a></td>
#  <td><a href="/gast/geschaefte/1971">Kleine Anfrage der SP-Fraktion betreffend Kampagne «Alter hat Potenzial»
#  </a></td>
#  <td class="hidden-xs">Antwort des Regierungsrats</td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Kleine Anfrage</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1970">2982</a></td>
#  <td><a href="/gast/geschaefte/1970">Interpellation von Daniel Stadlin betreffend Nutzung der Windenergie</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1969">2981</a></td>
#  <td><a href="/gast/geschaefte/1969">Änderung des Einführungsgesetzes zu den Bundesgesetzen über die Berufsbildung und Fachhochschulen (EG Berufsbildung) betreffend Führung einer Höheren Fachschule für Informatik und Elektronik am GIBZ</a></td>
#  <td class="hidden-xs">Kommission bestellt</td>
#  <td class="hidden-xs">Volkswirtschaftsdirektion</td>
#  <td class="hidden-xs">Gesetz</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1968">2980</a></td>
#  <td><a href="/gast/geschaefte/1968">Interpellation von Stéphanie Vuichard, Marianne Hess und Andreas Lustenberger betreffend Anstrengungen des Kantons zur Vermeidung von schädlicher und lästiger Lichteinwirkung</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1967">2979</a></td>
#  <td><a href="/gast/geschaefte/1967">Interpellation von Anna Bieri und Manuela Leemann betreffend Umgang mit Beurteilungen von überfachlichen Kompetenzen bei Kindern mit Autismus-Spektrumstörungen (ASS) und mit Aufmerksamkeitsdefizit-Störungen (ADS/ADHS)</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Direktion für Bildung und Kultur</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1966">2978</a></td>
#  <td><a href="/gast/geschaefte/1966">Interpellation von Ivo Egger, Andreas Hürlimann und Anastas Odermatt betreffend Mobilfunkstrahlenbelastung im Kanton Zug</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1965">2977</a></td>
#  <td><a href="/gast/geschaefte/1965">Postulat der SVP-Fraktion betreffend Förderung der Eigenverantwortung bei der Integration durch die Möglichkeit der Kostenbeteiligung für Kulturvermittler und Dolmetscher an Schulen</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Direktion für Bildung und Kultur</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1964">2976</a></td>
#  <td><a href="/gast/geschaefte/1964">Interpellation der SP-Fraktion betreffend Revision des Planungs- und Baugesetzes</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1963">2975</a></td>
#  <td><a href="/gast/geschaefte/1963">Interpellation der SP-Fraktion betreffend Einsatz von Insektiziden im Zuger Wald</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Direktion des Innern</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1962">2974</a></td>
#  <td><a href="/gast/geschaefte/1962">Postulat der SP-Fraktion betreffend wirksames Vorgehen gegen häusliche Gewalt</a></td>
#  <td class="hidden-xs">Traktandiert</td>
#  <td class="hidden-xs">Sicherheitsdirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1961">2973</a></td>
#  <td><a href="/gast/geschaefte/1961">Interpellation von Ivo Egger, Esther Haas, Hanni Schriber-Neiger betreffend Projektänderungen der Umfahrung Cham-Hünenberg</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1960">2972</a></td>
#  <td><a href="/gast/geschaefte/1960">Postulat von Tabea Zimmermann Gibson, Andreas Lustenberger und Mariann Hess betreffend nachhaltige Anlagestrategie der Zuger Pensionskasse</a></td>
#  <td class="hidden-xs">Traktandiert</td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1959">2971</a></td>
#  <td><a href="/gast/geschaefte/1959">Ersatzwahl eines neuen Mitglieds der Schätzungskommission für die restliche Amtsdauer 2019–2022</a></td>
#  <td class="hidden-xs">Wahl</td>
#  <td class="hidden-xs">Justizprüfungskommission</td>
#  <td class="hidden-xs">Wahlen</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1958">2970</a></td>
#  <td><a href="/gast/geschaefte/1958">Kantonsratsbeschluss betreffend Kenntnisnahme der Jahresrechnung 2018 und des Geschäftsberichts 2018 der Gebäudeversicherung Zug
#  </a></td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Sicherheitsdirektion</td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1957">2969</a></td>
#  <td><a href="/gast/geschaefte/1957">Rechenschaftsberichte 2017/2018 des Verwaltungsgerichts und der Schätzungskommission</a></td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Verwaltungsgericht</td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1956">2968</a></td>
#  <td><a href="/gast/geschaefte/1956">Zwischenbericht zu den per Ende März 2019 zur Berichterstattung fälligen parlamentarischen Vorstössen </a></td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Staatskanzlei</td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1954">2967</a></td>
#  <td><a href="/gast/geschaefte/1954">Interpellation von Manuela Leemann und Isabel Liniger betreffend Berücksichtigung des hindernisfreien Bauens bei Gesetzesprojekten</a></td>
#  <td class="hidden-xs">Traktandiert</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1953">2966</a></td>
#  <td><a href="/gast/geschaefte/1953">Postulat der CVP-Fraktion betreffend klimaneutralen öffentlichen Verkehr im Kanton Zug</a></td>
#  <td class="hidden-xs">Überweisung an Regierungsrat</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Postulat</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1955">2965</a></td>
#  <td><a href="/gast/geschaefte/1955">Feststellung der Gültigkeit der stillen Wahl eines Ersatzmitglieds des Obergerichts für den Rest der Amtsdauer 2019–2024</a></td>
#  <td class="hidden-xs">Wahl: Feststellung Gültigkeit</td>
#  <td class="hidden-xs">Staatskanzlei</td>
#  <td class="hidden-xs">Wahlen</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1951">2964</a></td>
#  <td><a href="/gast/geschaefte/1951">Kantonsratsbeschluss betreffend Objektkredit für die Planung der Instandsetzung und eines Neubaus an der Hofstrasse 15, Zug </a></td>
#  <td class="hidden-xs">Kommission bestellt</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Kantonsratsbeschluss (referendumsfähig)</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1952">2963</a></td>
#  <td><a href="/gast/geschaefte/1952">ZFA-Reform 2018: Abschlussbericht</a></td>
#  <td class="hidden-xs">Traktandiert</td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1950">2962</a></td>
#  <td><a href="/gast/geschaefte/1950">Interpellation der CVP-Fraktion betreffend bessere Beleuchtung und Energieoptimierung auf den Zuger Strassen insbesondere bei Fussgängerübergängen</a></td>
#  <td class="hidden-xs">Traktandiert</td>
#  <td class="hidden-xs">Baudirektion</td>
#  <td class="hidden-xs">Interpellation</td>
#  <td class="hidden-xs">hängig</td>
#  </tr>, <tr>
#  <td><a href="/gast/geschaefte/1949">2961</a></td>
#  <td><a href="/gast/geschaefte/1949">Geschäftsbericht 2018</a></td>
#  <td class="hidden-xs"></td>
#  <td class="hidden-xs">Finanzdirektion</td>
#  <td class="hidden-xs">Verschiedenes</td>
#  <td class="hidden-xs">abgeschlossen</td>
#  </tr>]

# %%
## Reto
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page="
seite = 1
while seite <= 40:
    print(url + str(seite))
    seite += 1

# %%
url = "https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=haengig&geschaeft_filter%5Bstatus_ids%5D%5B%5D=abgeschlossen&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page="
alleseiten = []

for seite in range(1,41):
    r = requests.get(url+str(seite))
    soup = BeautifulSoup(r.text, 'html.parser')
    
    trlist = soup.find_all("tr")[2:]
    
    for element in trlist:
    
        td_list = element.find_all('td')
        href = td_list[0].find('a')['href']
        geschäft = td_list[1].text
        stand = td_list[2].text
        zuständig = td_list[3].text
        geschäftsart = td_list[4].text
        status = td_list[5].text

        mini_dict = {"url":href,
          "geschäft": geschäft,
          "stand": stand,
          "zuständig": zuständig,
          "geschäftsart":geschäftsart,
          "status": status}
    
        alleseiten.append(mini_dict)

# %%
pd.DataFrame(alleseiten).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1963 entries, 0 to 1962
# Data columns (total 6 columns):
# geschäft        1963 non-null object
# geschäftsart    1963 non-null object
# stand           1963 non-null object
# status          1963 non-null object
# url             1963 non-null object
# zuständig       1963 non-null object
# dtypes: object(6)
# memory usage: 92.1+ KB

# %%
pd.DataFrame(alleseiten)
# Out:
#                                                geschäft  \
# 0     Postulat von Ivo Egger, Stéphanie Vuichard, Ha...
# 1     Postulat von Stéphanie Vuichard, Mariann Hess ...
# 2     Motion von Rainer Leemann und Michael Arnold b...
# 3     Interpellation der SP-Fraktion betreffend Pest...
# 4     Interpellation von Pirmin Andermatt und Heini ...
# 5     Kantonsrats-Ersatzwahl in der Einwohnergemeind...
# 6     Motion der CVP-Fraktion betreffend bedarfsgere...
# 7     Postulat von Manuela Leemann, Benny Elsener un...
# 8     Interpellation von Hans Baumgartner, Manuela K...
# 9     Kantonsrats-Ersatzwahl in der Einwohnergemeind...
# 10    Interpellation von Pirmin Andermatt, Zari Dzaf...
# 11    Motion der FDP-Fraktion betreffend mehr Kompet...
# 12    Kantonsratsbeschluss betreffend Kenntnisnahme ...
# 13    Kleine Anfrage von Andreas Lustenberger betref...
# 14    Kantonsratsbeschluss betreffend Beitritt zum G...
# 15    Interpellation der CVP-Fraktion betreffend Aus...
# 16    Interpellation der FDP-Fraktion betreffend kan...
# 17    Motion von Anna Bieri und Barbara Häseli betre...
# 18    Postulat der SP-Fraktion und der Fraktion Alte...
# 19    Kantonsratsbeschluss betreffend Anpassung des ...
# 20    Postulat von Fabio Iten und Patrick Iten betre...
# 21    Interpellation von Ivo Egger und Zari Dzaferi ...
# 22    Petition «Forderungen der Pflegefachfrauen der...
# 23                    Petition «Frauen*streik Manifest»
# 24    Geschäftsbericht 2018 der Kindes- und Erwachse...
# 25                     Änderung des Datenschutzgesetzes
# 26    Kleine Anfrage von Rita Hofer betreffend Umset...
# 27    Kleine Anfrage der SP-Fraktion betreffend Kamp...
# 28    Interpellation von Daniel Stadlin betreffend N...
# 29    Änderung des Einführungsgesetzes zu den Bundes...
# ...                                                 ...
# 1933  Motion von Marcel Meyer betreffend Vergabe von...
# 1934  Motion von Hans Abicht betreffend Raumkonzept ...
# 1935  Genehmigung der Schlussabrechnung für den Obje...
# 1936  Motion der erweiterten Justizprüfungskommissio...
# 1937  Genehmigung der Schlussabrechnung für den Neub...
# 1938  Genehmigung der Schlussabrechnung (K9) betreff...
# 1939  Genehmigung der Schlussabrechnung betreffend B...
# 1940          Genehmigung von acht Schlussabrechnungen:
# 1941          Genehmigung von acht Schlussabrechnungen:
# 1942  Motion der Kommission Teilrevision Personalges...
# 1943  Genehmigung der Schlussabrechnungen für den Er...
# 1944          Genehmigung von acht Schlussabrechnungen:
# 1945  Genehmigung der Schlussabrechnung für den Neub...
# 1946  Genehmigung der Schlussabrechnung betreffend N...
# 1947  Kantonsratsbeschluss betreffend Schlussabrechn...
# 1948          Genehmigung von acht Schlussabrechnungen:
# 1949          Genehmigung von acht Schlussabrechnungen:
# 1950  Genehmigung der Schlussabrechnung betreffend R...
# 1951          Genehmigung von acht Schlussabrechnungen:
# 1952  Genehmigung der Schlussabrechnung (K42) betref...
# 1953  Strassenbauprogramm 1998 - 2003, Schlussberich...
# 1954  Genehmigung der Schlussabrechnung betreffend B...
# 1955  Genehmigung der Schlussabrechnung für die Umfa...
# 1956          Genehmigung von acht Schlussabrechnungen:
# 1957  Genehmigung der Schlussabrechnung für das Vorp...
# 1958  Motion von Manuela Weichelt betreffend HIV-Prä...
# 1959  Motion von Christoph Hohler betreffend Radstre...
# 1960  Genehmigung der Schlussabrechnung (K98) betref...
# 1961  Genehmigung der Schlussabrechnung (K40) betref...
# 1962  Motion der vorberatenden Kommission betreffend...
#
#                                        geschäftsart  \
# 0                                          Postulat
# 1                                          Postulat
# 2                                            Motion
# 3                                    Interpellation
# 4                                    Interpellation
# 5                                            Wahlen
# 6                                            Motion
# 7                                          Postulat
# 8                                    Interpellation
# 9                                            Wahlen
# 10                                   Interpellation
# 11                                           Motion
# 12    Kantonsratsbeschluss (nicht referendumsfähig)
# 13                                   Kleine Anfrage
# 14                                        Konkordat
# 15                                   Interpellation
# 16                                   Interpellation
# 17                                           Motion
# 18                                         Postulat
# 19    Kantonsratsbeschluss (nicht referendumsfähig)
# 20                                         Postulat
# 21                                   Interpellation
# 22                                         Petition
# 23                                         Petition
# 24                                    Verschiedenes
# 25                                           Gesetz
# 26                                   Kleine Anfrage
# 27                                   Kleine Anfrage
# 28                                   Interpellation
# 29                                           Gesetz
# ...                                             ...
# 1933                                         Motion
# 1934                                         Motion
# 1935                                  Verschiedenes
# 1936                                         Motion
# 1937                                  Verschiedenes
# 1938                                  Verschiedenes
# 1939                                  Verschiedenes
# 1940                                  Verschiedenes
# 1941                                  Verschiedenes
# 1942                                         Motion
# 1943                                  Verschiedenes
# 1944                                  Verschiedenes
# 1945                                  Verschiedenes
# 1946                                  Verschiedenes
# 1947  Kantonsratsbeschluss (nicht referendumsfähig)
# 1948                                  Verschiedenes
# 1949                                  Verschiedenes
# 1950                                  Verschiedenes
# 1951                                  Verschiedenes
# 1952                                  Verschiedenes
# 1953                                  Verschiedenes
# 1954                                  Verschiedenes
# 1955                                  Verschiedenes
# 1956                                  Verschiedenes
# 1957                                  Verschiedenes
# 1958                                         Motion
# 1959                                         Motion
# 1960                                  Verschiedenes
# 1961                                  Verschiedenes
# 1962                                         Motion
#
#                               stand         status                    url  \
# 0                       Einreichung         hängig  /gast/geschaefte/1998
# 1                       Einreichung         hängig  /gast/geschaefte/1997
# 2                       Einreichung         hängig  /gast/geschaefte/1996
# 3                       Einreichung         hängig  /gast/geschaefte/1995
# 4                       Einreichung         hängig  /gast/geschaefte/1994
# 5                      Traktandiert         hängig  /gast/geschaefte/1993
# 6                       Einreichung         hängig  /gast/geschaefte/1992
# 7      Überweisung an Regierungsrat         hängig  /gast/geschaefte/1991
# 8      Überweisung an Regierungsrat         hängig  /gast/geschaefte/1990
# 9     Wahl: Feststellung Gültigkeit  abgeschlossen  /gast/geschaefte/1989
# 10     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1988
# 11     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1987
# 12              Kommission bestellt         hängig  /gast/geschaefte/1986
# 13       Antwort des Regierungsrats  abgeschlossen  /gast/geschaefte/1985
# 14              Kommission bestellt         hängig  /gast/geschaefte/1984
# 15     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1983
# 16     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1982
# 17               Erheblicherklärung         hängig  /gast/geschaefte/1981
# 18                 Nichtüberweisung  abgeschlossen  /gast/geschaefte/1979
# 19              Kommission bestellt         hängig  /gast/geschaefte/1980
# 20     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1978
# 21     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1977
# 22        Überweisung an Kommission         hängig  /gast/geschaefte/1976
# 23        Überweisung an Kommission         hängig  /gast/geschaefte/1975
# 24                                   abgeschlossen  /gast/geschaefte/1974
# 25              Kommission bestellt         hängig  /gast/geschaefte/1973
# 26       Antwort des Regierungsrats  abgeschlossen  /gast/geschaefte/1972
# 27       Antwort des Regierungsrats  abgeschlossen  /gast/geschaefte/1971
# 28     Überweisung an Regierungsrat         hängig  /gast/geschaefte/1970
# 29              Kommission bestellt         hängig  /gast/geschaefte/1969
# ...                             ...            ...                    ...
# 1933                 Datenmigration  abgeschlossen  /gast/geschaefte/1335
# 1934                 Datenmigration  abgeschlossen  /gast/geschaefte/1333
# 1935                 Datenmigration  abgeschlossen  /gast/geschaefte/1332
# 1936                 Datenmigration  abgeschlossen  /gast/geschaefte/1331
# 1937                 Datenmigration  abgeschlossen  /gast/geschaefte/1330
# 1938                 Datenmigration  abgeschlossen  /gast/geschaefte/1329
# 1939                 Datenmigration  abgeschlossen  /gast/geschaefte/1328
# 1940                 Datenmigration  abgeschlossen  /gast/geschaefte/1327
# 1941                 Datenmigration  abgeschlossen  /gast/geschaefte/1326
# 1942                 Datenmigration  abgeschlossen  /gast/geschaefte/1325
# 1943                 Datenmigration  abgeschlossen  /gast/geschaefte/1324
# 1944                 Datenmigration  abgeschlossen  /gast/geschaefte/1323
# 1945                 Datenmigration  abgeschlossen  /gast/geschaefte/1322
# 1946                 Datenmigration  abgeschlossen  /gast/geschaefte/1321
# 1947                 Datenmigration  abgeschlossen  /gast/geschaefte/1320
# 1948                 Datenmigration  abgeschlossen  /gast/geschaefte/1319
# 1949                 Datenmigration  abgeschlossen  /gast/geschaefte/1318
# 1950                 Datenmigration  abgeschlossen  /gast/geschaefte/1317
# 1951                 Datenmigration  abgeschlossen  /gast/geschaefte/1316
# 1952                 Datenmigration  abgeschlossen  /gast/geschaefte/1315
# 1953                 Datenmigration  abgeschlossen  /gast/geschaefte/1314
# 1954                 Datenmigration  abgeschlossen  /gast/geschaefte/1313
# 1955                 Datenmigration  abgeschlossen  /gast/geschaefte/1312
# 1956                 Datenmigration  abgeschlossen  /gast/geschaefte/1311
# 1957                 Datenmigration  abgeschlossen  /gast/geschaefte/1310
# 1958                 Datenmigration  abgeschlossen  /gast/geschaefte/1309
# 1959                Frist erstreckt         hängig  /gast/geschaefte/1712
# 1960                 Datenmigration  abgeschlossen  /gast/geschaefte/1308
# 1961                 Datenmigration  abgeschlossen  /gast/geschaefte/1307
# 1962                 Datenmigration  abgeschlossen  /gast/geschaefte/1334
#
#                              zuständig
# 0                         Baudirektion
# 1                         Baudirektion
# 2                 Gesundheitsdirektion
# 3                         Baudirektion
# 4                      Finanzdirektion
# 5                        Staatskanzlei
# 6     Direktion für Bildung und Kultur
# 7                         Baudirektion
# 8                         Baudirektion
# 9                        Staatskanzlei
# 10                        Baudirektion
# 11    Direktion für Bildung und Kultur
# 12           Volkswirtschaftsdirektion
# 13                Direktion des Innern
# 14                Sicherheitsdirektion
# 15                        Baudirektion
# 16                     Finanzdirektion
# 17                Gesundheitsdirektion
# 18                     Finanzdirektion
# 19                        Baudirektion
# 20                        Baudirektion
# 21                        Baudirektion
# 22            Justizprüfungskommission
# 23            Justizprüfungskommission
# 24            Justizprüfungskommission
# 25                Sicherheitsdirektion
# 26    Direktion für Bildung und Kultur
# 27                     Finanzdirektion
# 28                        Baudirektion
# 29           Volkswirtschaftsdirektion
# ...                                ...
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959                      Baudirektion
# 1960
# 1961
# 1962
#
# [1963 rows x 6 columns]
